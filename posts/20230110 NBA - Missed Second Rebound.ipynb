# %% [markdown]
# # Efficiency of Missed Second Rebounds

# %% [markdown]
# For poor free throw shooters, is it a better strategy to *intentionally* miss the second free throw and aim for the offensive rebound and new possession? Analysis of play-by-play data using [nba_api](https://github.com/swar/nba_api).

# %%
import numpy as np
import pandas as pd

# %%
#Get a list of team IDs
from nba_api.stats.static import teams

nba_teams = teams.get_teams()

# Select the dictionary for the Pacers, which contains their team ID
team_ids = [team['id'] for team in nba_teams]
print(f'team IDs found: {len(team_ids)}')
# Out:
# team IDs found: 30

# %%
# Query for the regular season games of the Cavs (team no. 3 alphabetically)
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_ids[2], 
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']
game_IDs = [game['GAME_ID'] for game in games]

# %%
games
# Out:
# [{'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200645',
#   'GAME_DATE': '2023-01-14',
#   'MATCHUP': 'CLE @ MIN',
#   'WL': 'L',
#   'MIN': 241,
#   'PTS': 102,
#   'FGM': 37,
#   'FGA': 76,
#   'FG_PCT': 0.487,
#   'FG3M': 8,
#   'FG3A': 28,
#   'FG3_PCT': 0.286,
#   'FTM': 20,
#   'FTA': 23,
#   'FT_PCT': 0.87,
#   'OREB': 8,
#   'DREB': 32,
#   'REB': 40,
#   'AST': 24,
#   'STL': 5,
#   'BLK': 2,
#   'TOV': 18,
#   'PF': 17,
#   'PLUS_MINUS': -8.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200631',
#   'GAME_DATE': '2023-01-12',
#   'MATCHUP': 'CLE @ POR',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 119,
#   'FGM': 44,
#   'FGA': 89,
#   'FG_PCT': 0.494,
#   'FG3M': 7,
#   'FG3A': 22,
#   'FG3_PCT': 0.318,
#   'FTM': 24,
#   'FTA': 31,
#   'FT_PCT': 0.774,
#   'OREB': 12,
#   'DREB': 32,
#   'REB': 44,
#   'AST': 28,
#   'STL': 6,
#   'BLK': 1,
#   'TOV': 11,
#   'PF': 19,
#   'PLUS_MINUS': 6.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200614',
#   'GAME_DATE': '2023-01-10',
#   'MATCHUP': 'CLE @ UTA',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 114,
#   'FGM': 42,
#   'FGA': 90,
#   'FG_PCT': 0.467,
#   'FG3M': 10,
#   'FG3A': 37,
#   'FG3_PCT': 0.27,
#   'FTM': 20,
#   'FTA': 24,
#   'FT_PCT': 0.833,
#   'OREB': 7,
#   'DREB': 30,
#   'REB': 37,
#   'AST': 18,
#   'STL': 7,
#   'BLK': 7,
#   'TOV': 5,
#   'PF': 25,
#   'PLUS_MINUS': -2.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200603',
#   'GAME_DATE': '2023-01-08',
#   'MATCHUP': 'CLE @ PHX',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 112,
#   'FGM': 45,
#   'FGA': 78,
#   'FG_PCT': 0.577,
#   'FG3M': 11,
#   'FG3A': 29,
#   'FG3_PCT': 0.379,
#   'FTM': 11,
#   'FTA': 17,
#   'FT_PCT': 0.647,
#   'OREB': 3,
#   'DREB': 36,
#   'REB': 39,
#   'AST': 29,
#   'STL': 8,
#   'BLK': 5,
#   'TOV': 14,
#   'PF': 12,
#   'PLUS_MINUS': 14.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200588',
#   'GAME_DATE': '2023-01-06',
#   'MATCHUP': 'CLE @ DEN',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 108,
#   'FGM': 40,
#   'FGA': 88,
#   'FG_PCT': 0.455,
#   'FG3M': 10,
#   'FG3A': 26,
#   'FG3_PCT': 0.385,
#   'FTM': 18,
#   'FTA': 32,
#   'FT_PCT': 0.563,
#   'OREB': 18,
#   'DREB': 22,
#   'REB': 40,
#   'AST': 30,
#   'STL': 7,
#   'BLK': 5,
#   'TOV': 6,
#   'PF': 18,
#   'PLUS_MINUS': -13.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200565',
#   'GAME_DATE': '2023-01-04',
#   'MATCHUP': 'CLE vs. PHX',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 90,
#   'FGM': 30,
#   'FGA': 77,
#   'FG_PCT': 0.39,
#   'FG3M': 11,
#   'FG3A': 36,
#   'FG3_PCT': 0.306,
#   'FTM': 19,
#   'FTA': 23,
#   'FT_PCT': 0.826,
#   'OREB': 7,
#   'DREB': 39,
#   'REB': 46,
#   'AST': 15,
#   'STL': 9,
#   'BLK': 4,
#   'TOV': 14,
#   'PF': 17,
#   'PLUS_MINUS': 2.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200552',
#   'GAME_DATE': '2023-01-02',
#   'MATCHUP': 'CLE vs. CHI',
#   'WL': 'W',
#   'MIN': 265,
#   'PTS': 145,
#   'FGM': 48,
#   'FGA': 92,
#   'FG_PCT': 0.522,
#   'FG3M': 16,
#   'FG3A': 46,
#   'FG3_PCT': 0.348,
#   'FTM': 33,
#   'FTA': 45,
#   'FT_PCT': 0.733,
#   'OREB': 13,
#   'DREB': 34,
#   'REB': 47,
#   'AST': 27,
#   'STL': 1,
#   'BLK': 3,
#   'TOV': 10,
#   'PF': 27,
#   'PLUS_MINUS': 11.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200540',
#   'GAME_DATE': '2022-12-31',
#   'MATCHUP': 'CLE @ CHI',
#   'WL': 'W',
#   'MIN': 242,
#   'PTS': 103,
#   'FGM': 39,
#   'FGA': 85,
#   'FG_PCT': 0.459,
#   'FG3M': 13,
#   'FG3A': 38,
#   'FG3_PCT': 0.342,
#   'FTM': 12,
#   'FTA': 19,
#   'FT_PCT': 0.632,
#   'OREB': 15,
#   'DREB': 35,
#   'REB': 50,
#   'AST': 20,
#   'STL': 9,
#   'BLK': 5,
#   'TOV': 20,
#   'PF': 18,
#   'PLUS_MINUS': 1.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200524',
#   'GAME_DATE': '2022-12-29',
#   'MATCHUP': 'CLE @ IND',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 126,
#   'FGM': 50,
#   'FGA': 96,
#   'FG_PCT': 0.521,
#   'FG3M': 12,
#   'FG3A': 28,
#   'FG3_PCT': 0.429,
#   'FTM': 14,
#   'FTA': 20,
#   'FT_PCT': 0.7,
#   'OREB': 17,
#   'DREB': 27,
#   'REB': 44,
#   'AST': 29,
#   'STL': 7,
#   'BLK': 4,
#   'TOV': 10,
#   'PF': 17,
#   'PLUS_MINUS': -9.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200498',
#   'GAME_DATE': '2022-12-26',
#   'MATCHUP': 'CLE vs. BKN',
#   'WL': 'L',
#   'MIN': 241,
#   'PTS': 117,
#   'FGM': 39,
#   'FGA': 82,
#   'FG_PCT': 0.476,
#   'FG3M': 13,
#   'FG3A': 36,
#   'FG3_PCT': 0.361,
#   'FTM': 26,
#   'FTA': 30,
#   'FT_PCT': 0.867,
#   'OREB': 10,
#   'DREB': 23,
#   'REB': 33,
#   'AST': 21,
#   'STL': 8,
#   'BLK': 3,
#   'TOV': 12,
#   'PF': 14,
#   'PLUS_MINUS': -8.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200484',
#   'GAME_DATE': '2022-12-23',
#   'MATCHUP': 'CLE vs. TOR',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 107,
#   'FGM': 39,
#   'FGA': 76,
#   'FG_PCT': 0.513,
#   'FG3M': 11,
#   'FG3A': 33,
#   'FG3_PCT': 0.333,
#   'FTM': 18,
#   'FTA': 30,
#   'FT_PCT': 0.6,
#   'OREB': 6,
#   'DREB': 29,
#   'REB': 35,
#   'AST': 27,
#   'STL': 9,
#   'BLK': 4,
#   'TOV': 14,
#   'PF': 17,
#   'PLUS_MINUS': -11.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200466',
#   'GAME_DATE': '2022-12-21',
#   'MATCHUP': 'CLE vs. MIL',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 114,
#   'FGM': 41,
#   'FGA': 85,
#   'FG_PCT': 0.482,
#   'FG3M': 10,
#   'FG3A': 32,
#   'FG3_PCT': 0.313,
#   'FTM': 22,
#   'FTA': 28,
#   'FT_PCT': 0.786,
#   'OREB': 9,
#   'DREB': 28,
#   'REB': 37,
#   'AST': 22,
#   'STL': 8,
#   'BLK': 3,
#   'TOV': 10,
#   'PF': 21,
#   'PLUS_MINUS': 8.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200452',
#   'GAME_DATE': '2022-12-19',
#   'MATCHUP': 'CLE vs. UTA',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 122,
#   'FGM': 43,
#   'FGA': 70,
#   'FG_PCT': 0.614,
#   'FG3M': 15,
#   'FG3A': 26,
#   'FG3_PCT': 0.577,
#   'FTM': 21,
#   'FTA': 26,
#   'FT_PCT': 0.808,
#   'OREB': 4,
#   'DREB': 41,
#   'REB': 45,
#   'AST': 24,
#   'STL': 5,
#   'BLK': 4,
#   'TOV': 21,
#   'PF': 20,
#   'PLUS_MINUS': 23.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200440',
#   'GAME_DATE': '2022-12-17',
#   'MATCHUP': 'CLE vs. DAL',
#   'WL': 'W',
#   'MIN': 265,
#   'PTS': 100,
#   'FGM': 40,
#   'FGA': 94,
#   'FG_PCT': 0.426,
#   'FG3M': 7,
#   'FG3A': 36,
#   'FG3_PCT': 0.194,
#   'FTM': 13,
#   'FTA': 22,
#   'FT_PCT': 0.591,
#   'OREB': 9,
#   'DREB': 42,
#   'REB': 51,
#   'AST': 23,
#   'STL': 6,
#   'BLK': 5,
#   'TOV': 10,
#   'PF': 24,
#   'PLUS_MINUS': 1.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200431',
#   'GAME_DATE': '2022-12-16',
#   'MATCHUP': 'CLE vs. IND',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 118,
#   'FGM': 38,
#   'FGA': 76,
#   'FG_PCT': 0.5,
#   'FG3M': 14,
#   'FG3A': 31,
#   'FG3_PCT': 0.452,
#   'FTM': 28,
#   'FTA': 32,
#   'FT_PCT': 0.875,
#   'OREB': 6,
#   'DREB': 28,
#   'REB': 34,
#   'AST': 23,
#   'STL': 6,
#   'BLK': 2,
#   'TOV': 8,
#   'PF': 15,
#   'PLUS_MINUS': 6.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200421',
#   'GAME_DATE': '2022-12-14',
#   'MATCHUP': 'CLE @ DAL',
#   'WL': 'W',
#   'MIN': 239,
#   'PTS': 105,
#   'FGM': 41,
#   'FGA': 78,
#   'FG_PCT': 0.526,
#   'FG3M': 8,
#   'FG3A': 24,
#   'FG3_PCT': 0.333,
#   'FTM': 15,
#   'FTA': 19,
#   'FT_PCT': 0.789,
#   'OREB': 5,
#   'DREB': 38,
#   'REB': 43,
#   'AST': 26,
#   'STL': 5,
#   'BLK': 2,
#   'TOV': 6,
#   'PF': 20,
#   'PLUS_MINUS': 15.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200406',
#   'GAME_DATE': '2022-12-12',
#   'MATCHUP': 'CLE @ SAS',
#   'WL': 'L',
#   'MIN': 241,
#   'PTS': 111,
#   'FGM': 45,
#   'FGA': 92,
#   'FG_PCT': 0.489,
#   'FG3M': 5,
#   'FG3A': 23,
#   'FG3_PCT': 0.217,
#   'FTM': 16,
#   'FTA': 17,
#   'FT_PCT': 0.941,
#   'OREB': 15,
#   'DREB': 29,
#   'REB': 44,
#   'AST': 21,
#   'STL': 7,
#   'BLK': 7,
#   'TOV': 15,
#   'PF': 13,
#   'PLUS_MINUS': -1.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200390',
#   'GAME_DATE': '2022-12-10',
#   'MATCHUP': 'CLE vs. OKC',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 110,
#   'FGM': 40,
#   'FGA': 85,
#   'FG_PCT': 0.471,
#   'FG3M': 12,
#   'FG3A': 32,
#   'FG3_PCT': 0.375,
#   'FTM': 18,
#   'FTA': 26,
#   'FT_PCT': 0.692,
#   'OREB': 12,
#   'DREB': 36,
#   'REB': 48,
#   'AST': 25,
#   'STL': 6,
#   'BLK': 4,
#   'TOV': 11,
#   'PF': 14,
#   'PLUS_MINUS': 8.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200381',
#   'GAME_DATE': '2022-12-09',
#   'MATCHUP': 'CLE vs. SAC',
#   'WL': 'L',
#   'MIN': 241,
#   'PTS': 95,
#   'FGM': 34,
#   'FGA': 79,
#   'FG_PCT': 0.43,
#   'FG3M': 10,
#   'FG3A': 30,
#   'FG3_PCT': 0.333,
#   'FTM': 17,
#   'FTA': 22,
#   'FT_PCT': 0.773,
#   'OREB': 8,
#   'DREB': 28,
#   'REB': 36,
#   'AST': 20,
#   'STL': 7,
#   'BLK': 4,
#   'TOV': 19,
#   'PF': 23,
#   'PLUS_MINUS': -11.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200360',
#   'GAME_DATE': '2022-12-06',
#   'MATCHUP': 'CLE vs. LAL',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 116,
#   'FGM': 48,
#   'FGA': 93,
#   'FG_PCT': 0.516,
#   'FG3M': 7,
#   'FG3A': 27,
#   'FG3_PCT': 0.259,
#   'FTM': 13,
#   'FTA': 17,
#   'FT_PCT': 0.765,
#   'OREB': 9,
#   'DREB': 35,
#   'REB': 44,
#   'AST': 25,
#   'STL': 11,
#   'BLK': 3,
#   'TOV': 7,
#   'PF': 20,
#   'PLUS_MINUS': 14.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200348',
#   'GAME_DATE': '2022-12-04',
#   'MATCHUP': 'CLE @ NYK',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 81,
#   'FGM': 29,
#   'FGA': 83,
#   'FG_PCT': 0.349,
#   'FG3M': 8,
#   'FG3A': 35,
#   'FG3_PCT': 0.229,
#   'FTM': 15,
#   'FTA': 20,
#   'FT_PCT': 0.75,
#   'OREB': 8,
#   'DREB': 31,
#   'REB': 39,
#   'AST': 17,
#   'STL': 7,
#   'BLK': 6,
#   'TOV': 17,
#   'PF': 15,
#   'PLUS_MINUS': -11.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200330',
#   'GAME_DATE': '2022-12-02',
#   'MATCHUP': 'CLE vs. ORL',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 107,
#   'FGM': 41,
#   'FGA': 84,
#   'FG_PCT': 0.488,
#   'FG3M': 16,
#   'FG3A': 42,
#   'FG3_PCT': 0.381,
#   'FTM': 9,
#   'FTA': 9,
#   'FT_PCT': 1.0,
#   'OREB': 5,
#   'DREB': 28,
#   'REB': 33,
#   'AST': 22,
#   'STL': 7,
#   'BLK': 5,
#   'TOV': 12,
#   'PF': 14,
#   'PLUS_MINUS': 11.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200312',
#   'GAME_DATE': '2022-11-30',
#   'MATCHUP': 'CLE vs. PHI',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 113,
#   'FGM': 45,
#   'FGA': 74,
#   'FG_PCT': 0.608,
#   'FG3M': 15,
#   'FG3A': 29,
#   'FG3_PCT': 0.517,
#   'FTM': 8,
#   'FTA': 10,
#   'FT_PCT': 0.8,
#   'OREB': 6,
#   'DREB': 34,
#   'REB': 40,
#   'AST': 28,
#   'STL': 10,
#   'BLK': 3,
#   'TOV': 18,
#   'PF': 13,
#   'PLUS_MINUS': 28.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200303',
#   'GAME_DATE': '2022-11-28',
#   'MATCHUP': 'CLE @ TOR',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 88,
#   'FGM': 34,
#   'FGA': 90,
#   'FG_PCT': 0.378,
#   'FG3M': 7,
#   'FG3A': 38,
#   'FG3_PCT': 0.184,
#   'FTM': 13,
#   'FTA': 16,
#   'FT_PCT': 0.813,
#   'OREB': 13,
#   'DREB': 34,
#   'REB': 47,
#   'AST': 21,
#   'STL': 7,
#   'BLK': 3,
#   'TOV': 9,
#   'PF': 18,
#   'PLUS_MINUS': -12.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200295',
#   'GAME_DATE': '2022-11-27',
#   'MATCHUP': 'CLE @ DET',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 102,
#   'FGM': 33,
#   'FGA': 77,
#   'FG_PCT': 0.429,
#   'FG3M': 8,
#   'FG3A': 28,
#   'FG3_PCT': 0.286,
#   'FTM': 28,
#   'FTA': 33,
#   'FT_PCT': 0.848,
#   'OREB': 10,
#   'DREB': 31,
#   'REB': 41,
#   'AST': 14,
#   'STL': 3,
#   'BLK': 4,
#   'TOV': 14,
#   'PF': 20,
#   'PLUS_MINUS': 8.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200280',
#   'GAME_DATE': '2022-11-25',
#   'MATCHUP': 'CLE @ MIL',
#   'WL': 'L',
#   'MIN': 239,
#   'PTS': 102,
#   'FGM': 34,
#   'FGA': 87,
#   'FG_PCT': 0.391,
#   'FG3M': 12,
#   'FG3A': 33,
#   'FG3_PCT': 0.364,
#   'FTM': 22,
#   'FTA': 26,
#   'FT_PCT': 0.846,
#   'OREB': 10,
#   'DREB': 31,
#   'REB': 41,
#   'AST': 12,
#   'STL': 9,
#   'BLK': 2,
#   'TOV': 9,
#   'PF': 17,
#   'PLUS_MINUS': -15.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200261',
#   'GAME_DATE': '2022-11-23',
#   'MATCHUP': 'CLE vs. POR',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 114,
#   'FGM': 41,
#   'FGA': 74,
#   'FG_PCT': 0.554,
#   'FG3M': 12,
#   'FG3A': 27,
#   'FG3_PCT': 0.444,
#   'FTM': 20,
#   'FTA': 23,
#   'FT_PCT': 0.87,
#   'OREB': 11,
#   'DREB': 28,
#   'REB': 39,
#   'AST': 22,
#   'STL': 4,
#   'BLK': 4,
#   'TOV': 16,
#   'PF': 14,
#   'PLUS_MINUS': 18.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200248',
#   'GAME_DATE': '2022-11-21',
#   'MATCHUP': 'CLE vs. ATL',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 114,
#   'FGM': 42,
#   'FGA': 70,
#   'FG_PCT': 0.6,
#   'FG3M': 10,
#   'FG3A': 19,
#   'FG3_PCT': 0.526,
#   'FTM': 20,
#   'FTA': 23,
#   'FT_PCT': 0.87,
#   'OREB': 3,
#   'DREB': 34,
#   'REB': 37,
#   'AST': 24,
#   'STL': 8,
#   'BLK': 3,
#   'TOV': 19,
#   'PF': 17,
#   'PLUS_MINUS': 7.8},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200244',
#   'GAME_DATE': '2022-11-20',
#   'MATCHUP': 'CLE vs. MIA',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 113,
#   'FGM': 44,
#   'FGA': 83,
#   'FG_PCT': 0.53,
#   'FG3M': 13,
#   'FG3A': 37,
#   'FG3_PCT': 0.351,
#   'FTM': 12,
#   'FTA': 16,
#   'FT_PCT': 0.75,
#   'OREB': 13,
#   'DREB': 36,
#   'REB': 49,
#   'AST': 31,
#   'STL': 7,
#   'BLK': 1,
#   'TOV': 19,
#   'PF': 23,
#   'PLUS_MINUS': 26.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200225',
#   'GAME_DATE': '2022-11-18',
#   'MATCHUP': 'CLE vs. CHA',
#   'WL': 'W',
#   'MIN': 289,
#   'PTS': 132,
#   'FGM': 49,
#   'FGA': 92,
#   'FG_PCT': 0.533,
#   'FG3M': 8,
#   'FG3A': 28,
#   'FG3_PCT': 0.286,
#   'FTM': 26,
#   'FTA': 32,
#   'FT_PCT': 0.813,
#   'OREB': 7,
#   'DREB': 43,
#   'REB': 50,
#   'AST': 25,
#   'STL': 8,
#   'BLK': 8,
#   'TOV': 19,
#   'PF': 25,
#   'PLUS_MINUS': 10.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200216',
#   'GAME_DATE': '2022-11-16',
#   'MATCHUP': 'CLE @ MIL',
#   'WL': 'L',
#   'MIN': 241,
#   'PTS': 98,
#   'FGM': 36,
#   'FGA': 84,
#   'FG_PCT': 0.429,
#   'FG3M': 12,
#   'FG3A': 28,
#   'FG3_PCT': 0.429,
#   'FTM': 14,
#   'FTA': 17,
#   'FT_PCT': 0.824,
#   'OREB': 6,
#   'DREB': 28,
#   'REB': 34,
#   'AST': 22,
#   'STL': 7,
#   'BLK': 7,
#   'TOV': 8,
#   'PF': 18,
#   'PLUS_MINUS': -15.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200193',
#   'GAME_DATE': '2022-11-13',
#   'MATCHUP': 'CLE vs. MIN',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 124,
#   'FGM': 40,
#   'FGA': 89,
#   'FG_PCT': 0.449,
#   'FG3M': 17,
#   'FG3A': 34,
#   'FG3_PCT': 0.5,
#   'FTM': 27,
#   'FTA': 39,
#   'FT_PCT': 0.692,
#   'OREB': 16,
#   'DREB': 24,
#   'REB': 40,
#   'AST': 22,
#   'STL': 6,
#   'BLK': 1,
#   'TOV': 10,
#   'PF': 22,
#   'PLUS_MINUS': -5.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200182',
#   'GAME_DATE': '2022-11-11',
#   'MATCHUP': 'CLE @ GSW',
#   'WL': 'L',
#   'MIN': 240,
#   'PTS': 101,
#   'FGM': 37,
#   'FGA': 92,
#   'FG_PCT': 0.402,
#   'FG3M': 8,
#   'FG3A': 30,
#   'FG3_PCT': 0.267,
#   'FTM': 19,
#   'FTA': 26,
#   'FT_PCT': 0.731,
#   'OREB': 14,
#   'DREB': 32,
#   'REB': 46,
#   'AST': 25,
#   'STL': 6,
#   'BLK': 3,
#   'TOV': 10,
#   'PF': 17,
#   'PLUS_MINUS': -5.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200171',
#   'GAME_DATE': '2022-11-09',
#   'MATCHUP': 'CLE @ SAC',
#   'WL': 'L',
#   'MIN': 239,
#   'PTS': 120,
#   'FGM': 46,
#   'FGA': 86,
#   'FG_PCT': 0.535,
#   'FG3M': 11,
#   'FG3A': 26,
#   'FG3_PCT': 0.423,
#   'FTM': 17,
#   'FTA': 20,
#   'FT_PCT': 0.85,
#   'OREB': 12,
#   'DREB': 30,
#   'REB': 42,
#   'AST': 24,
#   'STL': 4,
#   'BLK': 1,
#   'TOV': 18,
#   'PF': 23,
#   'PLUS_MINUS': -7.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200158',
#   'GAME_DATE': '2022-11-07',
#   'MATCHUP': 'CLE @ LAC',
#   'WL': 'L',
#   'MIN': 241,
#   'PTS': 117,
#   'FGM': 43,
#   'FGA': 83,
#   'FG_PCT': 0.518,
#   'FG3M': 16,
#   'FG3A': 33,
#   'FG3_PCT': 0.485,
#   'FTM': 15,
#   'FTA': 21,
#   'FT_PCT': 0.714,
#   'OREB': 10,
#   'DREB': 38,
#   'REB': 48,
#   'AST': 29,
#   'STL': 6,
#   'BLK': 2,
#   'TOV': 17,
#   'PF': 21,
#   'PLUS_MINUS': -2.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200140',
#   'GAME_DATE': '2022-11-06',
#   'MATCHUP': 'CLE @ LAL',
#   'WL': 'W',
#   'MIN': 240,
#   'PTS': 114,
#   'FGM': 37,
#   'FGA': 84,
#   'FG_PCT': 0.44,
#   'FG3M': 8,
#   'FG3A': 32,
#   'FG3_PCT': 0.25,
#   'FTM': 32,
#   'FTA': 36,
#   'FT_PCT': 0.889,
#   'OREB': 9,
#   'DREB': 39,
#   'REB': 48,
#   'AST': 19,
#   'STL': 7,
#   'BLK': 6,
#   'TOV': 12,
#   'PF': 20,
#   'PLUS_MINUS': 14.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200120',
#   'GAME_DATE': '2022-11-04',
#   'MATCHUP': 'CLE @ DET',
#   'WL': 'W',
#   'MIN': 239,
#   'PTS': 112,
#   'FGM': 44,
#   'FGA': 81,
#   'FG_PCT': 0.543,
#   'FG3M': 11,
#   'FG3A': 26,
#   'FG3_PCT': 0.423,
#   'FTM': 13,
#   'FTA': 16,
#   'FT_PCT': 0.813,
#   'OREB': 10,
#   'DREB': 37,
#   'REB': 47,
#   'AST': 30,
#   'STL': 5,
#   'BLK': 13,
#   'TOV': 18,
#   'PF': 15,
#   'PLUS_MINUS': 24.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200107',
#   'GAME_DATE': '2022-11-02',
#   'MATCHUP': 'CLE vs. BOS',
#   'WL': 'W',
#   'MIN': 265,
#   'PTS': 114,
#   'FGM': 42,
#   'FGA': 100,
#   'FG_PCT': 0.42,
#   'FG3M': 11,
#   'FG3A': 39,
#   'FG3_PCT': 0.282,
#   'FTM': 19,
#   'FTA': 24,
#   'FT_PCT': 0.792,
#   'OREB': 9,
#   'DREB': 42,
#   'REB': 51,
#   'AST': 24,
#   'STL': 6,
#   'BLK': 4,
#   'TOV': 11,
#   'PF': 23,
#   'PLUS_MINUS': 1.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200090',
#   'GAME_DATE': '2022-10-30',
#   'MATCHUP': 'CLE vs. NYK',
#   'WL': 'W',
#   'MIN': 238,
#   'PTS': 121,
#   'FGM': 41,
#   'FGA': 89,
#   'FG_PCT': 0.461,
#   'FG3M': 23,
#   'FG3A': 50,
#   'FG3_PCT': 0.46,
#   'FTM': 16,
#   'FTA': 19,
#   'FT_PCT': 0.842,
#   'OREB': 10,
#   'DREB': 33,
#   'REB': 43,
#   'AST': 33,
#   'STL': 3,
#   'BLK': 5,
#   'TOV': 14,
#   'PF': 22,
#   'PLUS_MINUS': 13.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200072',
#   'GAME_DATE': '2022-10-28',
#   'MATCHUP': 'CLE @ BOS',
#   'WL': 'W',
#   'MIN': 265,
#   'PTS': 132,
#   'FGM': 45,
#   'FGA': 87,
#   'FG_PCT': 0.517,
#   'FG3M': 16,
#   'FG3A': 35,
#   'FG3_PCT': 0.457,
#   'FTM': 26,
#   'FTA': 34,
#   'FT_PCT': 0.765,
#   'OREB': 9,
#   'DREB': 33,
#   'REB': 42,
#   'AST': 18,
#   'STL': 5,
#   'BLK': 2,
#   'TOV': 15,
#   'PF': 28,
#   'PLUS_MINUS': 9.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200056',
#   'GAME_DATE': '2022-10-26',
#   'MATCHUP': 'CLE vs. ORL',
#   'WL': 'W',
#   'MIN': 239,
#   'PTS': 103,
#   'FGM': 36,
#   'FGA': 87,
#   'FG_PCT': 0.414,
#   'FG3M': 10,
#   'FG3A': 33,
#   'FG3_PCT': 0.303,
#   'FTM': 21,
#   'FTA': 30,
#   'FT_PCT': 0.7,
#   'OREB': 12,
#   'DREB': 31,
#   'REB': 43,
#   'AST': 25,
#   'STL': 6,
#   'BLK': 3,
#   'TOV': 12,
#   'PF': 22,
#   'PLUS_MINUS': 11.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200039',
#   'GAME_DATE': '2022-10-23',
#   'MATCHUP': 'CLE vs. WAS',
#   'WL': 'W',
#   'MIN': 266,
#   'PTS': 117,
#   'FGM': 41,
#   'FGA': 96,
#   'FG_PCT': 0.427,
#   'FG3M': 13,
#   'FG3A': 33,
#   'FG3_PCT': 0.394,
#   'FTM': 22,
#   'FTA': 25,
#   'FT_PCT': 0.88,
#   'OREB': 16,
#   'DREB': 32,
#   'REB': 48,
#   'AST': 19,
#   'STL': 10,
#   'BLK': 5,
#   'TOV': 13,
#   'PF': 20,
#   'PLUS_MINUS': 10.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200032',
#   'GAME_DATE': '2022-10-22',
#   'MATCHUP': 'CLE @ CHI',
#   'WL': 'W',
#   'MIN': 241,
#   'PTS': 128,
#   'FGM': 48,
#   'FGA': 85,
#   'FG_PCT': 0.565,
#   'FG3M': 16,
#   'FG3A': 27,
#   'FG3_PCT': 0.593,
#   'FTM': 16,
#   'FTA': 18,
#   'FT_PCT': 0.889,
#   'OREB': 8,
#   'DREB': 40,
#   'REB': 48,
#   'AST': 32,
#   'STL': 4,
#   'BLK': 5,
#   'TOV': 17,
#   'PF': 17,
#   'PLUS_MINUS': 32.0},
#  {'SEASON_ID': '22022',
#   'TEAM_ID': 1610612739,
#   'TEAM_ABBREVIATION': 'CLE',
#   'TEAM_NAME': 'Cleveland Cavaliers',
#   'GAME_ID': '0022200008',
#   'GAME_DATE': '2022-10-19',
#   'MATCHUP': 'CLE @ TOR',
#   'WL': 'L',
#   'MIN': 242,
#   'PTS': 105,
#   'FGM': 38,
#   'FGA': 77,
#   'FG_PCT': 0.494,
#   'FG3M': 10,
#   'FG3A': 28,
#   'FG3_PCT': 0.357,
#   'FTM': 19,
#   'FTA': 23,
#   'FT_PCT': 0.826,
#   'OREB': 6,
#   'DREB': 32,
#   'REB': 38,
#   'AST': 25,
#   'STL': 5,
#   'BLK': 5,
#   'TOV': 17,
#   'PF': 21,
#   'PLUS_MINUS': -3.0}]

# %%
game_homeTeam = [game['MATCHUP'][-3:] if len(game['MATCHUP']) == 9 else game['MATCHUP'][0:3] for game in games]
game_homeTeam[18]
# Out:
# 'CLE'

# %%
testString = 'CLE @ MIN'
testString[-3:]
# Out:
# 'MIN'

# %%
game_IDs[18]
# Out:
# '0022200381'

# %%
game_id = "0022200552"

# %%
# Query for the play by play of that most recent regular season game
from nba_api.stats.endpoints import playbyplayv2
df = playbyplayv2.PlayByPlayV2(game_id).get_data_frames()[0]


#Convert the game clock time to seconds and re-order
df['PCTIME_SECONDS'] = df['PCTIMESTRING'].map(lambda x: int(x.split(":")[0])*60 + int(x.split(":")[1]))
df = df.sort_values(['PERIOD','PCTIME_SECONDS','EVENTNUM'], ascending=[True,False,True])
df = df.reset_index(drop=True)

#Update the SCORE column to fill in blanks
df.at[0,"SCORE"] = "0 - 0"
df["SCORE"] = df["SCORE"].fillna(method="ffill")

# %%
# Query for the play by play of that most recent regular season game
from nba_api.stats.endpoints import playbyplayv2
df_viol = playbyplayv2.PlayByPlayV2("0022200381").get_data_frames()[0]


#Convert the game clock time to seconds and re-order
df_viol['PCTIME_SECONDS'] = df_viol['PCTIMESTRING'].map(lambda x: int(x.split(":")[0])*60 + int(x.split(":")[1]))
df_viol = df_viol.sort_values(['PERIOD','PCTIME_SECONDS','EVENTNUM'], ascending=[True,False,True])
df_viol = df_viol.reset_index(drop=True)

#Update the SCORE column to fill in blanks
df_viol.at[0,"SCORE"] = "0 - 0"
df_viol["SCORE"] = df["SCORE"].fillna(method="ffill")

# %%
df_viol[df_viol['EVENTMSGTYPE'] == 5]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 8    0022200381        15             5                   1       1
# 17   0022200381        28             5                   1       1
# 26   0022200381        40             5                   4       1
# 32   0022200381        47             5                  11       1
# 39   0022200381        56             5                  37       1
# 54   0022200381        80             5                  11       1
# 55   0022200381        81             5                  39       1
# 69   0022200381       100             5                   1       1
# 85   0022200381       125             5                   4       1
# 92   0022200381       135             5                   2       1
# 98   0022200381       145             5                  37       1
# 115  0022200381       170             5                   2       2
# 122  0022200381       180             5                   2       2
# 147  0022200381       211             5                  45       2
# 152  0022200381       217             5                   2       2
# 153  0022200381       219             5                   4       2
# 222  0022200381       314             5                   2       2
# 238  0022200381       339             5                   4       2
# 275  0022200381       395             5                  45       3
# 288  0022200381       414             5                   2       3
# 305  0022200381       440             5                   8       3
# 323  0022200381       466             5                  37       3
# 325  0022200381       469             5                   4       3
# 330  0022200381       475             5                   1       3
# 344  0022200381       498             5                  45       4
# 347  0022200381       503             5                  37       4
# 349  0022200381       506             5                   1       4
# 350  0022200381       508             5                   2       4
# 357  0022200381       521             5                  37       4
# 360  0022200381       524             5                   2       4
# 361  0022200381       526             5                   4       4
# 370  0022200381       538             5                   1       4
# 381  0022200381       554             5                   1       4
# 382  0022200381       556             5                  45       4
# 383  0022200381       557             5                   1       4
# 396  0022200381       576             5                   2       4
# 427  0022200381       650             5                   2       4
# 431  0022200381       630             5                   4       4
# 446  0022200381       647             5                  11       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 8        7:42 PM        10:57
# 17       7:46 PM         9:42
# 26       7:48 PM         8:30
# 32       7:49 PM         7:30
# 39       7:50 PM         6:42
# 54       7:55 PM         4:56
# 55       7:56 PM         4:48
# 69       7:59 PM         3:47
# 85       8:03 PM         2:26
# 92       8:05 PM         1:44
# 98       8:06 PM         1:12
# 115      8:12 PM        11:18
# 122      8:13 PM        10:49
# 147      8:17 PM         9:02
# 152      8:18 PM         8:00
# 153      8:18 PM         7:55
# 222      8:35 PM         1:08
# 238      8:39 PM         0:03
# 275      9:04 PM         7:44
# 288      9:08 PM         5:46
# 305      9:14 PM         4:03
# 323      9:19 PM         2:45
# 325      9:20 PM         2:29
# 330      9:22 PM         1:21
# 344      9:28 PM        11:41
# 347      9:29 PM        11:17
# 349      9:29 PM        11:05
# 350      9:29 PM        10:56
# 357      9:32 PM        10:11
# 360      9:32 PM         9:39
# 361      9:32 PM         9:34
# 370      9:37 PM         8:26
# 381      9:39 PM         7:04
# 382      9:39 PM         6:46
# 383      9:40 PM         6:19
# 396      9:43 PM         4:54
# 427      9:51 PM         1:27
# 431      9:54 PM         1:11
# 446      9:57 PM         0:00
#
#                                        HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 8                      Allen Bad Pass Turnover (P1.T1)               None
# 17                     Allen Bad Pass Turnover (P2.T2)               None
# 26                                                None               None
# 32                                                None               None
# 39                                                None               None
# 54                                                None               None
# 55         Garland Step Out of Bounds Turnover (P1.T3)               None
# 69                     Allen Bad Pass Turnover (P3.T4)               None
# 85                                                None               None
# 92                    Okoro Lost Ball Turnover (P1.T5)               None
# 98                                                None               None
# 115                                 Neto STEAL (1 STL)               None
# 122                 Garland Lost Ball Turnover (P2.T6)               None
# 147                                               None               None
# 152                                Osman STEAL (1 STL)               None
# 153                 Garland Traveling Turnover (P3.T7)               None
# 222                                Osman STEAL (2 STL)               None
# 238                                               None               None
# 275  LeVert Out of Bounds - Bad Pass Turnover Turno...               None
# 288                              Garland STEAL (1 STL)               None
# 305         Mobley 3 Second Violation Turnover (P1.T9)               None
# 323                                               None               None
# 325                 Mobley Traveling Turnover (P2.T10)               None
# 330                  LeVert Bad Pass Turnover (P2.T11)               None
# 344  Allen Out of Bounds - Bad Pass Turnover Turnov...               None
# 347             Allen Offensive Foul Turnover (P5.T13)               None
# 349                                Osman STEAL (3 STL)               None
# 350                 Mobley Lost Ball Turnover (P3.T14)               None
# 357                                               None               None
# 360                Garland Lost Ball Turnover (P4.T15)               None
# 361                                               None               None
# 370                              Garland STEAL (2 STL)               None
# 381                  Mobley Bad Pass Turnover (P4.T16)               None
# 382                                               None               None
# 383                 Garland Bad Pass Turnover (P5.T17)               None
# 396                               Mobley STEAL (1 STL)               None
# 427                Garland Lost Ball Turnover (P6.T18)               None
# 431                  Osman Traveling Turnover (P1.T19)               None
# 446              CAVALIERS Turnover: Shot Clock (T#20)               None
#
#                                     VISITORDESCRIPTION  ...  \
# 8                                Huerter STEAL (1 STL)  ...
# 17                               Sabonis STEAL (1 STL)  ...
# 26                 Mitchell Traveling Turnover (P1.T1)  ...
# 32                    Kings Turnover: Shot Clock (T#2)  ...
# 39             Huerter Offensive Foul Turnover (P1.T3)  ...
# 54                    Kings Turnover: Shot Clock (T#4)  ...
# 55                                                None  ...
# 69                               Huerter STEAL (2 STL)  ...
# 85                   Barnes Traveling Turnover (P1.T5)  ...
# 92                           Dellavedova STEAL (1 STL)  ...
# 98         Dellavedova Offensive Foul Turnover (P1.T6)  ...
# 115                    Monk Lost Ball Turnover (P1.T7)  ...
# 122                               Murray STEAL (1 STL)  ...
# 147  Metu Out of Bounds - Bad Pass Turnover Turnove...  ...
# 152                 Sabonis Lost Ball Turnover (P1.T9)  ...
# 153                                               None  ...
# 222                   Monk Lost Ball Turnover (P2.T10)  ...
# 238                 Barnes Traveling Turnover (P2.T11)  ...
# 275                                               None  ...
# 288                 Barnes Lost Ball Turnover (P3.T12)  ...
# 305                                               None  ...
# 323            Barnes Offensive Foul Turnover (P4.T13)  ...
# 325                                               None  ...
# 330                          Dellavedova STEAL (2 STL)  ...
# 344                                               None  ...
# 347                                               None  ...
# 349                    Monk Bad Pass Turnover (P3.T14)  ...
# 350                                 Metu STEAL (1 STL)  ...
# 357             Lyles Offensive Foul Turnover (P1.T15)  ...
# 360                          Dellavedova STEAL (3 STL)  ...
# 361                   Monk Traveling Turnover (P4.T16)  ...
# 370                    Monk Bad Pass Turnover (P5.T17)  ...
# 381                              Huerter STEAL (3 STL)  ...
# 382  Mitchell Out of Bounds - Bad Pass Turnover Tur...  ...
# 383                              Sabonis STEAL (2 STL)  ...
# 396                Sabonis Lost Ball Turnover (P2.T19)  ...
# 427                              Sabonis STEAL (3 STL)  ...
# 431                                               None  ...
# 446                                               None  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 8                         SAC           0           0          None
# 17                        SAC           0           0          None
# 26                       None           1           0          None
# 32                       None           1           0          None
# 39                       None           1           0          None
# 54                       None           1           0          None
# 55                       None           1           0          None
# 69                        SAC           0           0          None
# 85                       None           1           0          None
# 92                        SAC           0           0          None
# 98                       None           1           0          None
# 115                       CLE           0           0          None
# 122                       SAC           0           0          None
# 147                      None           1           0          None
# 152                       CLE           0           0          None
# 153                      None           1           0          None
# 222                       CLE           0           0          None
# 238                      None           1           0          None
# 275                      None           0           0          None
# 288                       CLE           0           0          None
# 305                      None           1           0          None
# 323                      None           1           0          None
# 325                      None           1           0          None
# 330                       SAC           0           0          None
# 344                      None           1           0          None
# 347                      None           1           0          None
# 349                       CLE           0           0          None
# 350                       SAC           0           0          None
# 357                      None           1           0          None
# 360                       SAC           0           0          None
# 361                      None           1           0          None
# 370                       CLE           0           0          None
# 381                       SAC           0           0          None
# 382                      None           1           0          None
# 383                       SAC           0           0          None
# 396                       CLE           0           0          None
# 427                       SAC           0           0          None
# 431                      None           1           0          None
# 446                      None           1           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 8               NaN               None                  None
# 17              NaN               None                  None
# 26              NaN               None                  None
# 32              NaN               None                  None
# 39              NaN               None                  None
# 54              NaN               None                  None
# 55              NaN               None                  None
# 69              NaN               None                  None
# 85              NaN               None                  None
# 92              NaN               None                  None
# 98              NaN               None                  None
# 115             NaN               None                  None
# 122             NaN               None                  None
# 147             NaN               None                  None
# 152             NaN               None                  None
# 153             NaN               None                  None
# 222             NaN               None                  None
# 238             NaN               None                  None
# 275             NaN               None                  None
# 288             NaN               None                  None
# 305             NaN               None                  None
# 323             NaN               None                  None
# 325             NaN               None                  None
# 330             NaN               None                  None
# 344             NaN               None                  None
# 347             NaN               None                  None
# 349             NaN               None                  None
# 350             NaN               None                  None
# 357             NaN               None                  None
# 360             NaN               None                  None
# 361             NaN               None                  None
# 370             NaN               None                  None
# 381             NaN               None                  None
# 382             NaN               None                  None
# 383             NaN               None                  None
# 396             NaN               None                  None
# 427             NaN               None                  None
# 431             NaN               None                  None
# 446             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 8                        None                    1             657
# 17                       None                    1             582
# 26                       None                    1             510
# 32                       None                    1             450
# 39                       None                    1             402
# 54                       None                    1             296
# 55                       None                    1             288
# 69                       None                    1             227
# 85                       None                    1             146
# 92                       None                    1             104
# 98                       None                    1              72
# 115                      None                    1             678
# 122                      None                    1             649
# 147                      None                    1             542
# 152                      None                    1             480
# 153                      None                    1             475
# 222                      None                    1              68
# 238                      None                    1               3
# 275                      None                    1             464
# 288                      None                    1             346
# 305                      None                    1             243
# 323                      None                    1             165
# 325                      None                    1             149
# 330                      None                    1              81
# 344                      None                    1             701
# 347                      None                    1             677
# 349                      None                    1             665
# 350                      None                    1             656
# 357                      None                    1             611
# 360                      None                    1             579
# 361                      None                    1             574
# 370                      None                    1             506
# 381                      None                    1             424
# 382                      None                    1             406
# 383                      None                    1             379
# 396                      None                    1             294
# 427                      None                    1              87
# 431                      None                    1              71
# 446                      None                    1               0
#
# [39 rows x 35 columns]

# %%
df_viol.iloc[204:209]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 204  0022200645       298             6                   1       2
# 205  0022200645       300             7                   5       2
# 206  0022200645       301             8                   0       2
# 207  0022200645       303             1                  52       2
# 208  0022200645       305             1                   9       2
#
#     WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 204      9:05 PM         1:23           McDaniels P.FOUL (P3.T4) (K.Scott)
# 205      9:06 PM         1:16      Nowell Violation:Kicked Ball (T.Maddox)
# 206      9:06 PM         1:16                  SUB: Anderson FOR McDaniels
# 207      9:06 PM         1:07                                         None
# 208      9:07 PM         0:45  Reid 1' Driving Dunk (6 PTS) (Rivers 1 AST)
#
#     NEUTRALDESCRIPTION                                 VISITORDESCRIPTION  \
# 204               None                                               None
# 205               None                                               None
# 206               None                                               None
# 207               None  Allen 1' Alley Oop Dunk (11 PTS) (Mitchell 2 AST)
# 208               None                                               None
#
#      ... PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 204  ...                       CLE           1           0          None
# 205  ...                      None           1           0          None
# 206  ...                       MIN           0           0          None
# 207  ...                       CLE           0           0          None
# 208  ...                       MIN           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 204             NaN               None                  None
# 205             NaN               None                  None
# 206             NaN               None                  None
# 207             NaN               None                  None
# 208             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 204                      None                    1              83
# 205                      None                    0              76
# 206                      None                    0              76
# 207                      None                    1              67
# 208                      None                    1              45
#
# [5 rows x 35 columns]

# %%
#Find missed last free throws
missed_FTs = df.index[df['EVENTMSGACTIONTYPE'].isin([10,12,15]) & df['SCORE'].isna()].tolist()

for freethrow in missed_FTs:
    if df.loc[freethrow]['PLAYER1_ID'] == df.loc[freethrow+1]['PLAYER1_ID'] and df.loc[freethrow+1]['EVENTMSGTYPE'] == 4:
        print(f'self-offensive rebound - EVENTNUM: {df.loc[freethrow]["EVENTNUM"]}')
# Out:
# self-offensive rebound - EVENTNUM: 701

# %%
#Find offensive rebounds
missedShots = df.index[df['EVENTMSGTYPE'] == 2].tolist()

OREBs = []
for shot in missedShots:
    if df.loc[shot]['PLAYER1_TEAM_ID'] == df.loc[shot+1]['PLAYER1_TEAM_ID'] and df.loc[shot+1]['EVENTMSGTYPE'] == 4:
        print(f'offensive rebound - LOC: {shot}')
        OREBs.append(shot+1)
# Out:
# offensive rebound - LOC: 71
# offensive rebound - LOC: 103
# offensive rebound - LOC: 114
# offensive rebound - LOC: 176
# offensive rebound - LOC: 275
# offensive rebound - LOC: 290
# offensive rebound - LOC: 302
# offensive rebound - LOC: 313
# offensive rebound - LOC: 353
# offensive rebound - LOC: 388
# offensive rebound - LOC: 415
# offensive rebound - LOC: 422
# offensive rebound - LOC: 436
# offensive rebound - LOC: 466
# offensive rebound - LOC: 470
# offensive rebound - LOC: 500
# offensive rebound - LOC: 515
# offensive rebound - LOC: 525

# %%
missedShots
# Out:
# [3,
#  5,
#  11,
#  21,
#  24,
#  26,
#  28,
#  30,
#  59,
#  64,
#  71,
#  80,
#  82,
#  84,
#  86,
#  89,
#  99,
#  103,
#  111,
#  114,
#  120,
#  136,
#  138,
#  149,
#  151,
#  155,
#  157,
#  161,
#  166,
#  168,
#  171,
#  176,
#  181,
#  183,
#  185,
#  188,
#  195,
#  208,
#  222,
#  228,
#  230,
#  236,
#  240,
#  245,
#  247,
#  249,
#  251,
#  264,
#  267,
#  275,
#  284,
#  290,
#  297,
#  302,
#  313,
#  321,
#  335,
#  340,
#  353,
#  365,
#  367,
#  376,
#  378,
#  386,
#  388,
#  390,
#  398,
#  411,
#  413,
#  415,
#  417,
#  422,
#  428,
#  436,
#  439,
#  452,
#  460,
#  466,
#  470,
#  495,
#  500,
#  503,
#  505,
#  508,
#  510,
#  512,
#  515,
#  518,
#  522,
#  525,
#  528,
#  543]

# %%
#Find offensive rebounds for cleaned DF
missedShots2 = df2.index[df2['EVENTMSGTYPE'] == 2].tolist()

for shot in missedShots2:
    if (df2.iloc[shot]['PLAYER1_TEAM_ID'] == df2.iloc[shot+1]['PLAYER1_TEAM_ID']):
        print(f'offensive rebound - LOC: {shot}')
# Out:
# offensive rebound - LOC: 69
# offensive rebound - LOC: 98
# offensive rebound - LOC: 107
# offensive rebound - LOC: 164
# offensive rebound - LOC: 168
# offensive rebound - LOC: 255
# offensive rebound - LOC: 262
# offensive rebound - LOC: 277
# offensive rebound - LOC: 289
# offensive rebound - LOC: 300
# offensive rebound - LOC: 340
# offensive rebound - LOC: 364
# offensive rebound - LOC: 373
# offensive rebound - LOC: 400
# offensive rebound - LOC: 407
# offensive rebound - LOC: 421
# offensive rebound - LOC: 424
# offensive rebound - LOC: 449
# offensive rebound - LOC: 453
# offensive rebound - LOC: 482
# offensive rebound - LOC: 496
# offensive rebound - LOC: 506

# %%
#Find offensive rebounds for cleaned DF
missedShots2 = df2.index[df2['EVENTMSGTYPE'] == 2].tolist()

ORBs_2 = []
for shot in missedShots2:
    if (df2.iloc[shot]['PLAYER1_TEAM_ID'] == df2.iloc[shot+1]['PLAYER1_TEAM_ID']) and (df2.iloc[shot+1]['EVENTMSGTYPE'] == 4):
        print(f'offensive rebound - LOC: {shot}')
        ORBs_2.append(shot+1)
# Out:
# offensive rebound - LOC: 69
# offensive rebound - LOC: 98
# offensive rebound - LOC: 107
# offensive rebound - LOC: 168
# offensive rebound - LOC: 262
# offensive rebound - LOC: 277
# offensive rebound - LOC: 289
# offensive rebound - LOC: 300
# offensive rebound - LOC: 340
# offensive rebound - LOC: 373
# offensive rebound - LOC: 400
# offensive rebound - LOC: 407
# offensive rebound - LOC: 421
# offensive rebound - LOC: 449
# offensive rebound - LOC: 453
# offensive rebound - LOC: 482
# offensive rebound - LOC: 496
# offensive rebound - LOC: 506

# %%
play_loc = 70 + 1


# Go through df for first relevant event:
# EVENTMSGTYPE ==  1 - Made shot
#              ==  2 - Missed shot
#              ==  4 - Rebound
#              ==  6 - Foul
#              == 13 - Period End

while not df2.iloc[play_loc]['EVENTMSGTYPE'] in [1,2,4,6,13]:
    play_loc += 1
    
print(f'LOC: {play_loc}, EVENTMSGTYPE: {df2.iloc[play_loc]["EVENTMSGTYPE"]}')
# Out:
# LOC: 71, EVENTMSGTYPE: 6

# %%
def eventScore(start,end,df):
    
    start_score = df.iloc[start]['SCORE'].split(" - ")
    end_score = df.iloc[end]['SCORE'].split(" - ")
    
    diff_score = [int(x) - int(y) for x, y in zip(end_score, start_score)]
    
    return max(diff_score)

# %% [markdown]
# ### Random Functions

# %%
def extraRows(df_slice, df):
    
    # For a slice of a dataframe, shows the next two rows after each original row in the slice
    # Messy utility that gives more context to individual plays matching a criteria
    
    nextRows = df_slice.index.to_list()
    nextRows_new = [row + 1 for row in nextRows] + nextRows
    nextRows_new += [row + 2 for row in nextRows]
    nextRows_new.sort()
    
    return df.iloc[nextRows_new]

# %%
# Example of using the extraRows function
extraRows(df[df['EVENTMSGTYPE'] == 6],df)
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 7    0022200552        12             6                   2       1
# 8    0022200552        14             3                  11       1
# 9    0022200552        15             3                  12       1
# 13   0022200552        22             6                   2       1
# 14   0022200552        24             3                  10       1
# ..          ...       ...           ...                 ...     ...
# 516  0022200552       767             9                   1       5
# 517  0022200552       769            18                   6       5
# 521  0022200552       774             6                   1       5
# 522  0022200552       776             3                  11       5
# 523  0022200552       777             3                  12       5
#
#     WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 7        7:12 PM        11:05                                         None
# 8        7:13 PM        11:05           Mitchell Free Throw 1 of 2 (1 PTS)
# 9        7:13 PM        11:05              MISS Mitchell Free Throw 2 of 2
# 13       7:14 PM        10:38                                         None
# 14       7:14 PM        10:38                 MISS Allen Free Throw 1 of 1
# ..           ...          ...                                          ...
# 516      9:59 PM         0:41  CAVALIERS Timeout: Regular (Full 9 Short 0)
# 517      9:59 PM         0:41                                         None
# 521     10:01 PM         0:31                                         None
# 522     10:01 PM         0:31          Mitchell Free Throw 1 of 2 (70 PTS)
# 523     10:02 PM         0:31          Mitchell Free Throw 2 of 2 (71 PTS)
#
#                      NEUTRALDESCRIPTION                    VISITORDESCRIPTION  \
# 7                                  None  Williams S.FOUL (P1.T1) (T.Brothers)
# 8                                  None                                  None
# 9                                  None                                  None
# 13                                 None      DeRozan S.FOUL (P1.T2) (S.Mehta)
# 14                                 None                                  None
# ..                                  ...                                   ...
# 516                                None                                  None
# 517  Instant Replay1st OT (9:59 PM EST)                                  None
# 521                                None   Jones Jr. P.FOUL (P4.PN) (J.DeRosa)
# 522                                None                                  None
# 523                                None                                  None
#
#      ... PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 7    ...                       CLE           1           0          None
# 8    ...                      None           0           0          None
# 9    ...                      None           0           0          None
# 13   ...                       CLE           1           0          None
# 14   ...                      None           0           0          None
# ..   ...                       ...         ...         ...           ...
# 516  ...                      None           0           0          None
# 517  ...                      None           1           0          None
# 521  ...                       CLE           1           0          None
# 522  ...                      None           0           0          None
# 523  ...                      None           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 7               NaN               None                  None
# 8               NaN               None                  None
# 9               NaN               None                  None
# 13              NaN               None                  None
# 14              NaN               None                  None
# ..              ...                ...                   ...
# 516             NaN               None                  None
# 517             NaN               None                  None
# 521             NaN               None                  None
# 522             NaN               None                  None
# 523             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 7                        None                    1             665
# 8                        None                    1             665
# 9                        None                    1             665
# 13                       None                    1             638
# 14                       None                    1             638
# ..                        ...                  ...             ...
# 516                      None                    0              41
# 517                      None                    1              41
# 521                      None                    1              31
# 522                      None                    1              31
# 523                      None                    1              31
#
# [192 rows x 35 columns]

# %% [markdown]
# ### Turnovers and Period Ends
# Where `EVENTMSGTYPE == 5` or `EVENTMSGTYPE == 13`

# %%
def quickPoss(play_loc, df):
    
    possession = {"start_loc":   play_loc,
                  "end_loc":     play_loc,
                  "score":       0,
                  "play_end":    False,
                  "description": ""}
    
    if df.iloc[play_loc]['EVENTMSGACTIONTYPE'] == 5:
        possession["play_end"] = True
        possession["description"] = "Turnover"
        
    elif df.iloc[play_loc]['EVENTMSGACTIONTYPE'] == 13:
        possession["play_end"] = True
        possession["description"] = "Quarter end"
        
    return possession

# %% [markdown]
# ### Fouls
# Where `EVENTMSGTYPE == 6`

# %%
# Function for EVENTMSGTYPE == 6 (foul)
def checkFT(play_loc, df):
    
    # Initialise the possession info to be returned
    start_loc = play_loc
    possession = {"start_loc":   start_loc,
                  "end_loc":     start_loc,
                  "score":       0,
                  "play_end":    False,
                  "description": "Nothing yet..."}
    
    # Check if it's an offensive foul, i.e. a turnover
    if df.iloc[play_loc]['EVENTMSGACTIONTYPE'] == 4:
        possession["description"] = "Offensive foul turnover"
        possession["play_end"] = True
        possession["end_loc"] = play_loc + 1 #Offensive foul turnovers are described in two events
        return possession
    
    # For non-shooting fouls, check if FTs are taken
    play_loc += 1
    while df.iloc[play_loc]['PCTIME_SECONDS'] == df.iloc[play_loc - 1]['PCTIME_SECONDS']:

        if (df.iloc[play_loc]['EVENTMSGACTIONTYPE'] in [10,12,15]):

            # Check if the last FT was missed and which team got the rebound
            if (df.iloc[play_loc+1]['EVENTMSGTYPE'] == 4):
                possession = checkRebound(play_loc, possession, df)

            # Otherwise it was a made FT
            else:
                possession["play_end"] = True
                possession["description"] = "Made last FT"

            # Add the score from the made FTs (if any)
            diff_score = eventScore(start_loc,play_loc,df)
            possession["score"] += diff_score

            possession["end_loc"] = play_loc
            return possession

        else:
            play_loc += 1

    # If no last FTs are found with the same time code, it was a non-shooting foul
    possession["description"] = "Non-Shooting foul"
    possession["end_loc"] = play_loc + 1
    return possession

# %%
# Testing the checkFT function

poss = checkFT(211,df)

print(f'{poss["description"]}\nScore: {poss["score"]}')
if poss["play_end"]:
    print('Possession ended')
df.iloc[poss['start_loc']:poss['end_loc']+1]
# Out:
# Made last FT
# Score: 1
# Possession ended
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 211  0022200552       308             6                   2       2
# 212  0022200552       310             3                  10       2
#
#     WCTIMESTRING PCTIMESTRING                      HOMEDESCRIPTION  \
# 211      8:06 PM         0:39                                 None
# 212      8:06 PM         0:39  Mitchell Free Throw 1 of 1 (16 PTS)
#
#     NEUTRALDESCRIPTION                VISITORDESCRIPTION  ...  \
# 211               None  Caruso S.FOUL (P2.T4) (J.DeRosa)  ...
# 212               None                              None  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 211                       CLE           1           0          None
# 212                      None           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 211             NaN               None                  None
# 212             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 211                      None                    1              39
# 212                      None                    1              39
#
# [2 rows x 35 columns]

# %%
# Looking at offensive fouls

off_fouls = df[df['EVENTMSGACTIONTYPE'] == 4].index.to_list()
off_fouls += [foul + 1 for foul in off_fouls]
off_fouls.sort()

df.iloc[off_fouls]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 110  0022200552       178             5                   4       2
# 111  0022200552       179             8                   0       2
# 156  0022200552       243             6                   4       2
# 157  0022200552       245             5                  37       2
# 205  0022200552       313             6                   4       2
# 206  0022200552       315             5                  37       2
# 292  0022200552       447             6                   4       3
# 293  0022200552       449             5                  37       3
#
#     WCTIMESTRING PCTIMESTRING                           HOMEDESCRIPTION  \
# 110      7:43 PM        10:31          Lopez Traveling Turnover (P1.T4)
# 111      7:44 PM        10:31                                      None
# 156      7:55 PM         5:23                                      None
# 157      7:55 PM         5:23                                      None
# 205      8:07 PM         0:08       Mitchell OFF.Foul (P2) (T.Brothers)
# 206      8:07 PM         0:08  Mitchell Offensive Foul Turnover (P3.T8)
# 292      8:47 PM         3:34                                      None
# 293      8:47 PM         3:34                                      None
#
#     NEUTRALDESCRIPTION                       VISITORDESCRIPTION  ...  \
# 110               None                                     None  ...
# 111               None                  SUB: Dosunmu FOR Caruso  ...
# 156               None          Vucevic OFF.Foul (P2) (S.Mehta)  ...
# 157               None  Vucevic Offensive Foul Turnover (P1.T2)  ...
# 205               None                                     None  ...
# 206               None                                     None  ...
# 292               None        LaVine OFF.Foul (P3) (T.Brothers)  ...
# 293               None   LaVine Offensive Foul Turnover (P3.T5)  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 110                      None           1           0          None
# 111                       CHI           0           0          None
# 156                       CLE           1           0          None
# 157                      None           1           0          None
# 205                       CHI           1           0          None
# 206                      None           1           0          None
# 292                       CLE           1           0          None
# 293                      None           1           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 110             NaN               None                  None
# 111             NaN               None                  None
# 156             NaN               None                  None
# 157             NaN               None                  None
# 205             NaN               None                  None
# 206             NaN               None                  None
# 292             NaN               None                  None
# 293             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 110                      None                    1             631
# 111                      None                    0             631
# 156                      None                    1             323
# 157                      None                    1             323
# 205                      None                    1               8
# 206                      None                    1               8
# 292                      None                    1             214
# 293                      None                    1             214
#
# [8 rows x 35 columns]

# %%
missed_FTs
# Out:
# [9, 15, 97, 129, 146, 280, 426, 433, 457, 464, 488]

# %% [markdown]
# ### Made Field Goals
# Basically just checking for and-1s and adding the points from the shot

# %%
# Function for EVENTMSGTYPE == 1 (made FG)
def checkFG_made(play_loc,df):
    
    FG_score = eventScore(play_loc-1,play_loc,df)
    
    # Check if it's a shooting foul too, excluding when the next play is a foul from the same team
    if (df.iloc[play_loc + 1]['EVENTMSGTYPE'] == 6) and not (df.iloc[play_loc]['PLAYER1_TEAM_ID'] == df.iloc[play_loc + 1]['PLAYER1_TEAM_ID']):
        possession = checkFT(play_loc, df)
    
    # If just a made shot, return a standard possession dict with the score added
    else:
        possession = {"start_loc":   play_loc,
                      "end_loc":     play_loc,
                      "score":       0,
                      "play_end":    False,
                      "description": ""}
        
    possession['score'] += FG_score
    
    return possession

# %%
# Testing the checkFG_made function
poss = checkFG_made(210,df)

print(f'{poss["description"]}\nScore: {poss["score"]}')
df.iloc[poss['start_loc']:poss['end_loc']+1]
# Out:
# 211
# 212
# last FT found
# Made last FT
# Score: 4
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 210  0022200552       307             1                  80       2
# 211  0022200552       308             6                   2       2
# 212  0022200552       310             3                  10       2
# 213  0022200552       311             1                   1       2
#
#     WCTIMESTRING PCTIMESTRING                                HOMEDESCRIPTION  \
# 210      8:06 PM         0:39  Mitchell 27' 3PT Step Back Jump Shot (15 PTS)
# 211      8:06 PM         0:39                                           None
# 212      8:06 PM         0:39            Mitchell Free Throw 1 of 1 (16 PTS)
# 213      8:07 PM         0:29                                           None
#
#     NEUTRALDESCRIPTION                                 VISITORDESCRIPTION  \
# 210               None                                               None
# 211               None                   Caruso S.FOUL (P2.T4) (J.DeRosa)
# 212               None                                               None
# 213               None  LaVine 28' 3PT Jump Shot (10 PTS) (DeRozan 2 AST)
#
#      ... PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 210  ...                      None           0           0          None
# 211  ...                       CLE           1           0          None
# 212  ...                      None           0           0          None
# 213  ...                       CHI           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 210             NaN               None                  None
# 211             NaN               None                  None
# 212             NaN               None                  None
# 213             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 210                      None                    1              39
# 211                      None                    1              39
# 212                      None                    1              39
# 213                      None                    1              29
#
# [4 rows x 35 columns]

# %%
df.iloc[205:230]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 205  0022200552       301             4                   1       2
# 206  0022200552       302             3                  12       2
# 207  0022200552       303             1                  75       2
# 208  0022200552       305             2                   1       2
# 209  0022200552       306             4                   0       2
# 210  0022200552       307             1                  80       2
# 211  0022200552       308             6                   2       2
# 212  0022200552       310             3                  10       2
# 213  0022200552       311             1                   1       2
# 214  0022200552       313             6                   4       2
# 215  0022200552       315             5                  37       2
# 216  0022200552       316             6                  11       2
# 217  0022200552       317             3                  16       2
# 218  0022200552       318            13                   0       2
# 219  0022200552       321            18                   0       2
# 220  0022200552       330            12                   0       3
# 221  0022200552       331             6                   1       3
# 222  0022200552       333             2                   1       3
# 223  0022200552       334             4                   0       3
# 224  0022200552       335             5                  40       3
# 225  0022200552       338             6                  17       3
# 226  0022200552       339             3                  16       3
# 227  0022200552       340             6                   1       3
# 228  0022200552       342             2                   1       3
# 229  0022200552       343             4                   0       3
#
#     WCTIMESTRING PCTIMESTRING  \
# 205      8:05 PM         1:21
# 206      8:05 PM         1:21
# 207      8:05 PM         1:02
# 208      8:06 PM         0:46
# 209      8:06 PM         0:44
# 210      8:06 PM         0:39
# 211      8:06 PM         0:39
# 212      8:06 PM         0:39
# 213      8:07 PM         0:29
# 214      8:07 PM         0:08
# 215      8:07 PM         0:08
# 216      8:07 PM         0:08
# 217      8:08 PM         0:08
# 218      8:08 PM         0:00
# 219      8:09 PM         0:00
# 220      8:24 PM        12:00
# 221      8:24 PM        11:49
# 222      8:25 PM        11:46
# 223      8:25 PM        11:43
# 224      8:25 PM        11:35
# 225      8:26 PM        11:26
# 226      8:26 PM        11:26
# 227      8:26 PM        11:22
# 228      8:26 PM        11:18
# 229      8:26 PM        11:16
#
#                                        HOMEDESCRIPTION  \
# 205                                               None
# 206                                               None
# 207  Mitchell 2' Driving Finger Roll Layup (12 PTS)...
# 208                                               None
# 209                     Mitchell REBOUND (Off:0 Def:1)
# 210      Mitchell 27' 3PT Step Back Jump Shot (15 PTS)
# 211                                               None
# 212                Mitchell Free Throw 1 of 1 (16 PTS)
# 213                                               None
# 214                Mitchell OFF.Foul (P2) (T.Brothers)
# 215           Mitchell Offensive Foul Turnover (P3.T8)
# 216               Mitchell T.FOUL (P2.PN) (T.Brothers)
# 217                                               None
# 218                                               None
# 219                                               None
# 220                                               None
# 221                                               None
# 222                        MISS Love 25' 3PT Jump Shot
# 223                                               None
# 224                                               None
# 225                                               None
# 226             Mitchell Free Throw Technical (17 PTS)
# 227                                               None
# 228                        MISS Love 31' 3PT Jump Shot
# 229                                               None
#
#                          NEUTRALDESCRIPTION  \
# 205                                    None
# 206                                    None
# 207                                    None
# 208                                    None
# 209                                    None
# 210                                    None
# 211                                    None
# 212                                    None
# 213                                    None
# 214                                    None
# 215                                    None
# 216                                    None
# 217                                    None
# 218         End of 2nd Period (8:08 PM EST)
# 219  Instant Replay2nd Period (8:09 PM EST)
# 220       Start of 3rd Period (8:24 PM EST)
# 221                                    None
# 222                                    None
# 223                                    None
# 224                                    None
# 225                                    None
# 226                                    None
# 227                                    None
# 228                                    None
# 229                                    None
#
#                                     VISITORDESCRIPTION  ...  \
# 205                                      Bulls Rebound  ...
# 206                 DeRozan Free Throw 2 of 2 (18 PTS)  ...
# 207                                               None  ...
# 208                     MISS Vucevic 24' 3PT Jump Shot  ...
# 209                                               None  ...
# 210                                               None  ...
# 211                   Caruso S.FOUL (P2.T4) (J.DeRosa)  ...
# 212                                               None  ...
# 213  LaVine 28' 3PT Jump Shot (10 PTS) (DeRozan 2 AST)  ...
# 214                                               None  ...
# 215                                               None  ...
# 216                                               None  ...
# 217               LaVine Free Throw Technical (11 PTS)  ...
# 218                                               None  ...
# 219                                               None  ...
# 220                                               None  ...
# 221                  Dosunmu P.FOUL (P2.T1) (J.DeRosa)  ...
# 222                                               None  ...
# 223                      Vucevic REBOUND (Off:0 Def:7)  ...
# 224    LaVine Out of Bounds Lost Ball Turnover (P2.T3)  ...
# 225    Bulls T.Foul (Def. 3 Sec DeRozan ) (T.Brothers)  ...
# 226                                               None  ...
# 227                  Dosunmu P.FOUL (P3.T2) (J.DeRosa)  ...
# 228                                               None  ...
# 229                                      Bulls Rebound  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 205                      None           0           0          None
# 206                      None           0           0          None
# 207                       CLE           0           0          None
# 208                      None           0           0          None
# 209                      None           0           0          None
# 210                      None           0           0          None
# 211                       CLE           1           0          None
# 212                      None           0           0          None
# 213                       CHI           0           0          None
# 214                       CHI           1           0          None
# 215                      None           1           0          None
# 216                      None           1           0          None
# 217                      None           0           0          None
# 218                      None           0           0          None
# 219                      None           1           0          None
# 220                      None           0           0          None
# 221                       CLE           1           0          None
# 222                      None           0           0          None
# 223                      None           0           0          None
# 224                      None           1           0          None
# 225                      None           1           0          None
# 226                      None           0           0          None
# 227                       CLE           1           0          None
# 228                      None           0           0          None
# 229                      None           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 205             NaN               None                  None
# 206             NaN               None                  None
# 207             NaN               None                  None
# 208             NaN               None                  None
# 209             NaN               None                  None
# 210             NaN               None                  None
# 211             NaN               None                  None
# 212             NaN               None                  None
# 213             NaN               None                  None
# 214             NaN               None                  None
# 215             NaN               None                  None
# 216             NaN               None                  None
# 217             NaN               None                  None
# 218             NaN               None                  None
# 219             NaN               None                  None
# 220             NaN               None                  None
# 221             NaN               None                  None
# 222             NaN               None                  None
# 223             NaN               None                  None
# 224             NaN               None                  None
# 225             NaN               None                  None
# 226             NaN               None                  None
# 227             NaN               None                  None
# 228             NaN               None                  None
# 229             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 205                      None                    0              81
# 206                      None                    1              81
# 207                      None                    1              62
# 208                      None                    1              46
# 209                      None                    1              44
# 210                      None                    1              39
# 211                      None                    1              39
# 212                      None                    1              39
# 213                      None                    1              29
# 214                      None                    1               8
# 215                      None                    1               8
# 216                      None                    0               8
# 217                      None                    1               8
# 218                      None                    1               0
# 219                      None                    0               0
# 220                      None                    0             720
# 221                      None                    1             709
# 222                      None                    1             706
# 223                      None                    1             703
# 224                      None                    1             695
# 225                      None                    1             686
# 226                      None                    1             686
# 227                      None                    1             682
# 228                      None                    1             678
# 229                      None                    1             676
#
# [25 rows x 35 columns]

# %% [markdown]
# ### Missed FGs

# %%
def checkRebound(play_loc, possession, df):

    if df.iloc[play_loc]['PLAYER1_TEAM_ID'] == df.iloc[play_loc+1]['PLAYER1_TEAM_ID']:
        possession["description"] = "Miss - OREB"
    else:
        possession["description"] = "Miss - DREB"
        possession["play_end"] = True
        
    return possession

# %%
# Testing the checkRebound function
play_loc = 208

poss = {"start_loc":   play_loc,
        "end_loc":     play_loc,
        "score":       0,
        "play_end":    False,
        "description": ""}


poss = checkRebound(play_loc,poss,df)

print(f'{poss["description"]}\nScore: {poss["score"]}')
df.iloc[poss['start_loc']:poss['end_loc']+1]
# Out:
# Miss - DREB
# Score: 0
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 208  0022200552       305             2                   1       2
#
#     WCTIMESTRING PCTIMESTRING HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 208      8:06 PM         0:46            None               None
#
#                  VISITORDESCRIPTION  ... PLAYER2_TEAM_ABBREVIATION  \
# 208  MISS Vucevic 24' 3PT Jump Shot  ...                      None
#
#     PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY  \
# 208           0           0          None             NaN               None
#
#     PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  \
# 208                  None                      None                    1
#
#      PCTIME_SECONDS
# 208              46
#
# [1 rows x 35 columns]

# %%
df.iloc[3:6]
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 3  0022200552         8             2                 101       1
# 4  0022200552         9             4                   0       1
# 5  0022200552        10             2                  41       1
#
#   WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 3      7:12 PM        11:17  MISS Mitchell 6' Driving Floating Jump Shot
# 4      7:12 PM        11:15                                         None
# 5      7:12 PM        11:10                                         None
#
#   NEUTRALDESCRIPTION             VISITORDESCRIPTION  ...  \
# 3               None                           None  ...
# 4               None  Vucevic REBOUND (Off:0 Def:1)  ...
# 5               None  MISS Dosunmu 1' Running Layup  ...
#
#   PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 3                      None           0           0          None
# 4                      None           0           0          None
# 5                      None           0           0          None
#
#   PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 3             NaN               None                  None
# 4             NaN               None                  None
# 5             NaN               None                  None
#
#   PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 3                      None                    1             677
# 4                      None                    1             675
# 5                      None                    1             670
#
# [3 rows x 35 columns]

# %%
extraRows(df[(df['EVENTMSGTYPE'] == 7)],df)
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 362  0022200552       530             7                   3       4
# 363  0022200552       531             7                   3       4
# 363  0022200552       531             7                   3       4
# 364  0022200552       532             3                  15       4
# 364  0022200552       532             3                  15       4
# 365  0022200552       533             2                  79       4
# 385  0022200552       563             7                   5       4
# 386  0022200552       564             2                  80       4
# 387  0022200552       565             4                   0       4
#
#     WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 362      9:04 PM        11:19                                         None
# 363      9:05 PM        11:19                                         None
# 363      9:05 PM        11:19                                         None
# 364      9:05 PM        11:19          Mitchell Free Throw 3 of 3 (42 PTS)
# 364      9:05 PM        11:19          Mitchell Free Throw 3 of 3 (42 PTS)
# 365      9:05 PM        11:01                                         None
# 385      9:09 PM         8:45  Mitchell Violation:Kicked Ball (T.Brothers)
# 386      9:10 PM         8:29                                         None
# 387      9:10 PM         8:27                  Love REBOUND (Off:0 Def:11)
#
#     NEUTRALDESCRIPTION                   VISITORDESCRIPTION  ...  \
# 362               None                                 Lane  ...
# 363               None                                 Lane  ...
# 363               None                                 Lane  ...
# 364               None                                 None  ...
# 364               None                                 None  ...
# 365               None    MISS DeRozan 17' Pullup Jump Shot  ...
# 385               None                                 None  ...
# 386               None  MISS LaVine 22' Step Back Jump Shot  ...
# 387               None                                 None  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 362                      None           0           0          None
# 363                      None           0           0          None
# 363                      None           0           0          None
# 364                      None           0           0          None
# 364                      None           0           0          None
# 365                      None           0           0          None
# 385                      None           1           0          None
# 386                      None           0           0          None
# 387                      None           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 362             NaN               None                  None
# 363             NaN               None                  None
# 363             NaN               None                  None
# 364             NaN               None                  None
# 364             NaN               None                  None
# 365             NaN               None                  None
# 385             NaN               None                  None
# 386             NaN               None                  None
# 387             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 362                      None                    0             679
# 363                      None                    0             679
# 363                      None                    0             679
# 364                      None                    1             679
# 364                      None                    1             679
# 365                      None                    1             661
# 385                      None                    0             525
# 386                      None                    1             509
# 387                      None                    1             507
#
# [9 rows x 35 columns]

# %%
OREBs
# Out:
# [72,
#  104,
#  115,
#  177,
#  276,
#  291,
#  303,
#  314,
#  354,
#  389,
#  416,
#  423,
#  437,
#  467,
#  471,
#  501,
#  516,
#  526]

# %% [markdown]
# ### Option 1 - Possession Class

# %%
class Possession:
    def __init__(self, start=1, df=df, complete=False, description=""):
        self.df = df
        self.start = start
        self.end = start
        self.complete = complete
        self.score = 0
        self.description = description
        self.time_elapsed = 0
        
        self.team = self.df.iloc[self.start]['PLAYER1_TEAM_ID']
        
    def __repr__(self):
        return f'Possession: loc {self.start}-{self.end}; {self.description}'
    
    def view(self):
        return self.df.iloc[self.start : self.end + 1]
    
    
    def possession(self):
        while not self.complete:
            
            event_msg = self.df.iloc[self.end]['EVENTMSGTYPE']
            
            if event_msg == 1:
                self.madeFG()
            elif event_msg == 2:
                self.checkRebound()
            elif event_msg == 6:
                self.checkFoul()
            elif event_msg in [5,13]:
                self.endPossession()
            else:
                self.end += 1
        
        self.time_elapsed = self.df.iloc[self.start]['PCTIME_SECONDS'] - self.df.iloc[self.end]['PCTIME_SECONDS']
    
    
    def madeFG(self):
    
        # If it's a shooting foul, go through the FT loop
        if (self.df.iloc[self.end + 1]['EVENTMSGTYPE'] == 6) and (self.df.iloc[self.end]['PCTIME_SECONDS'] == self.df.iloc[self.end + 1]['PCTIME_SECONDS']):
            self.checkFoul()

        # If just a made shot, add the score and end the possession
        else:
            self.eventScore()
            self.complete = True
    
    
    def checkFoul(self):

        # Check if it's an offensive foul, i.e. a turnover
        if self.df.iloc[self.end]['EVENTMSGACTIONTYPE'] == 4:
            self.description = "Offensive foul turnover"
            self.complete = True
            self.end += 1 #Offensive foul turnovers are described in two events
            return

        # Check if FTs are taken
        self.end += 1
        while self.df.iloc[self.end]['PCTIME_SECONDS'] == self.df.iloc[self.end - 1]['PCTIME_SECONDS']:

            if self.df.iloc[self.end]['EVENTMSGACTIONTYPE'] in [10,12,15]:

                # Check if the last FT was missed and which team got the rebound
                if (self.df.iloc[self.end + 1]['EVENTMSGTYPE'] == 4):
                    self.checkRebound()

                # Otherwise it was a made FT
                else:
                    self.complete = True
                    self.description = "Made last FT"

                # Add the score from the made FTs (if any)
                self.eventScore()
                return

            else:
                self.end += 1

        # If no last FTs are found with the same time code, it was a non-shooting foul
        self.description = "Non-Shooting foul"
        self.end += 1
    
    
    def endPossession(self):
        if self.df.iloc[self.end]['EVENTMSGTYPE'] == 5:
            self.complete = True
            self.description = "Turnover"
        
        elif self.df.iloc[self.end]['EVENTMSGTYPE'] == 13:
            self.complete = True
            self.description = "Quarter end"
    
    
    def checkRebound(self):
        
        if self.df.iloc[self.end]['PLAYER1_TEAM_ID'] == self.df.iloc[self.end+1]['PLAYER1_TEAM_ID']:
            self.description = "Miss - OREB"
        else:
            self.description = "Miss - DREB"
            self.complete = True
    
    
    def eventScore(self):
    
        start_score = self.df.iloc[self.start]['SCORE'].split(" - ")
        end_score = self.df.iloc[self.end]['SCORE'].split(" - ")

        diff_score = [int(x) - int(y) for x, y in zip(end_score, start_score)]

        self.score += max(diff_score)

# %%
poss1 = Possession(209)

# %%
poss1.possession()

# %%
poss1.view()
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 209  0022200552       306             4                   0       2
# 210  0022200552       307             1                  80       2
# 211  0022200552       308             6                   2       2
# 212  0022200552       310             3                  10       2
#
#     WCTIMESTRING PCTIMESTRING                                HOMEDESCRIPTION  \
# 209      8:06 PM         0:44                 Mitchell REBOUND (Off:0 Def:1)
# 210      8:06 PM         0:39  Mitchell 27' 3PT Step Back Jump Shot (15 PTS)
# 211      8:06 PM         0:39                                           None
# 212      8:06 PM         0:39            Mitchell Free Throw 1 of 1 (16 PTS)
#
#     NEUTRALDESCRIPTION                VISITORDESCRIPTION  ...  \
# 209               None                              None  ...
# 210               None                              None  ...
# 211               None  Caruso S.FOUL (P2.T4) (J.DeRosa)  ...
# 212               None                              None  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 209                      None           0           0          None
# 210                      None           0           0          None
# 211                       CLE           1           0          None
# 212                      None           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 209             NaN               None                  None
# 210             NaN               None                  None
# 211             NaN               None                  None
# 212             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 209                      None                    1              44
# 210                      None                    1              39
# 211                      None                    1              39
# 212                      None                    1              39
#
# [4 rows x 35 columns]

# %%
poss1.score
# Out:
# 4

# %%
poss2 = Possession(213)

# %%
poss2.possession()
# Out:
# looping
# made FG
# should be done here

# %%
poss2.view()
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 213  0022200552       311             1                   1       2
#
#     WCTIMESTRING PCTIMESTRING HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 213      8:07 PM         0:29            None               None
#
#                                     VISITORDESCRIPTION  ...  \
# 213  LaVine 28' 3PT Jump Shot (10 PTS) (DeRozan 2 AST)  ...
#
#     PLAYER2_TEAM_ABBREVIATION PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME  \
# 213                       CHI           0           0          None
#
#     PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 213             NaN               None                  None
#
#     PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  PCTIME_SECONDS
# 213                      None                    1              29
#
# [1 rows x 35 columns]

# %%
poss3 = Possession(214)

# %%
poss3.possession()
# Out:
# looping
# foul

# %%
poss3.view()
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 214  0022200552       313             6                   4       2
# 215  0022200552       315             5                  37       2
#
#     WCTIMESTRING PCTIMESTRING                           HOMEDESCRIPTION  \
# 214      8:07 PM         0:08       Mitchell OFF.Foul (P2) (T.Brothers)
# 215      8:07 PM         0:08  Mitchell Offensive Foul Turnover (P3.T8)
#
#     NEUTRALDESCRIPTION VISITORDESCRIPTION  ... PLAYER2_TEAM_ABBREVIATION  \
# 214               None               None  ...                       CHI
# 215               None               None  ...                      None
#
#     PERSON3TYPE  PLAYER3_ID  PLAYER3_NAME PLAYER3_TEAM_ID  PLAYER3_TEAM_CITY  \
# 214           1           0          None             NaN               None
# 215           1           0          None             NaN               None
#
#     PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  \
# 214                  None                      None                    1
# 215                  None                      None                    1
#
#      PCTIME_SECONDS
# 214               8
# 215               8
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Option 2 - New df Column(s)

# %%
df['EVENTMSGTYPE_1'] = df['EVENTMSGTYPE'].shift(-1)
df['EVENTMSGACTIONTYPE_1'] = df['EVENTMSGACTIONTYPE'].shift(-1)
df['PCTIME_SECONDS_1'] = df['PCTIME_SECONDS'].shift(-1)
df['PLAYER1_TEAM_ID_1'] = df['PLAYER1_TEAM_ID'].shift(-1)
df['SCORE_1'] = df['SCORE'].shift(1)
df.at[0,'SCORE_1'] = "0 - 0"

# %%
df.head(5)
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0022200552         2            12                   0       1
# 1  0022200552         4            10                   0       1
# 2  0022200552         7             1                   1       1
# 3  0022200552         8             2                 101       1
# 4  0022200552         9             4                   0       1
#
#   WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 0      7:11 PM        12:00                                         None
# 1      7:11 PM        12:00  Jump Ball Allen vs. Vucevic: Tip to Dosunmu
# 2      7:12 PM        11:41                                         None
# 3      7:12 PM        11:17  MISS Mitchell 6' Driving Floating Jump Shot
# 4      7:12 PM        11:15                                         None
#
#                   NEUTRALDESCRIPTION                 VISITORDESCRIPTION  ...  \
# 0  Start of 1st Period (7:11 PM EST)                               None  ...
# 1                               None                               None  ...
# 2                               None  DeRozan 24' 3PT Jump Shot (3 PTS)  ...
# 3                               None                               None  ...
# 4                               None      Vucevic REBOUND (Off:0 Def:1)  ...
#
#   PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  PLAYER3_TEAM_ABBREVIATION  \
# 0              None                  None                       None
# 1           Chicago                 Bulls                        CHI
# 2              None                  None                       None
# 3              None                  None                       None
# 4              None                  None                       None
#
#    VIDEO_AVAILABLE_FLAG PCTIME_SECONDS  EVENTMSGTYPE_1 EVENTMSGACTIONTYPE_1  \
# 0                     0            720            10.0                  0.0
# 1                     1            720             1.0                  1.0
# 2                     1            701             2.0                101.0
# 3                     1            677             4.0                  0.0
# 4                     1            675             2.0                 41.0
#
#   PCTIME_SECONDS_1 PLAYER1_TEAM_ID_1  SCORE_1
# 0            720.0      1.610613e+09    0 - 0
# 1            701.0      1.610613e+09    0 - 0
# 2            677.0      1.610613e+09    0 - 0
# 3            675.0      1.610613e+09    3 - 0
# 4            670.0      1.610613e+09    3 - 0
#
# [5 rows x 40 columns]

# %%
# df['new_column_name'] = df.apply(lambda x: my_function(x['value_1'], x['value_2']), axis=1)

def possEndFG(loc, df):
    # Check if it's a shooting foul: the next play is a foul with the same time code
    if (df.iloc[loc]['EVENTMSGTYPE_1'] == 6) and (df.iloc[loc]['PCTIME_SECONDS'] == df.iloc[loc]['PCTIME_SECONDS_1']):
        return False
    else:
        return True
    
def possEndRebound(loc, df):
    # Check for offensive rebound: the next play (i.e. the rebound after a miss) is by the same team
    if df.iloc[loc]['PLAYER1_TEAM_ID'] == df.iloc[loc]['PLAYER1_TEAM_ID_1']:
        return False
    else:
        return True

def possEndFT(loc, df):
    # Check for offensive rebound 
    if df.iloc[loc]['EVENTMSGACTIONTYPE'] in [10,12,15]:
        if (df.iloc[loc]['EVENTMSGTYPE_1'] == 4):
            return possEndRebound(loc, df)
        else:
            return True
    else:
        return False

possOutcomesDict = {
    '1': possEndFG,
    '2': possEndRebound,
    '3': possEndFT
}

def possEndCheck(loc, df):
    
    if df.iloc[loc]['EVENTMSGTYPE'] in [1,2,3]:
        #print(f"running {possOutcomesDict[str(df.iloc[loc]['EVENTMSGTYPE'])]}")
        return possOutcomesDict[str(df.iloc[loc]['EVENTMSGTYPE'])](loc, df)
    elif df.iloc[loc]['EVENTMSGTYPE'] in [5,13]:
        return True
    else:
        return False

# %%
possEndCheck(8, df)
# Out:
# False

# %%
possEnd = []
for loc in range(len(df)):
    possEnd_row = possEndCheck(loc, df)
    possEnd.append(possEnd_row)

# %%
possEnd = [possEndCheck(loc, df) for loc in range(len(df))]

# %%
df["POSSESSION_END"] = possEnd

# %%
teamInPoss = [df.loc[1]["PLAYER3_TEAM_ABBREVIATION"]]

# %%
teamInPoss
# Out:
# ['CHI']

# %%
currentTeam = [df.loc[1]["PLAYER3_TEAM_ABBREVIATION"]][0]
teamNames = list(filter(lambda x: x is not None, df["PLAYER1_TEAM_ABBREVIATION"].unique().tolist()))
switch = True

teamInPoss = []

for idx, loc in enumerate(range(len(df))):
    
    teamInPoss.append(currentTeam)

    if df.iloc[loc]["POSSESSION_END"]:
        currentTeam = teamNames[int(not switch)]
        switch = not switch

# %%
df["POSSESSION_TEAM_ABBREVIATION"] = teamInPoss

# %%
df[(df["POSSESSION_END"]) & (df["POSSESSION_TEAM_ABBREVIATION"] == "CLE")]
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 3    0022200552         8             2                 101       1
# 8    0022200552        14             3                  11       1
# 13   0022200552        20             1                  98       1
# 18   0022200552        27             5                   1       1
# 21   0022200552        33             2                   1       1
# ..          ...       ...           ...                 ...     ...
# 524  0022200552       751             1                  80       5
# 528  0022200552       756             2                   1       5
# 533  0022200552       764             1                  79       5
# 541  0022200552       776             3                  11       5
# 545  0022200552       780            13                   0       5
#
#     WCTIMESTRING PCTIMESTRING  \
# 3        7:12 PM        11:17
# 8        7:13 PM        11:05
# 13       7:14 PM        10:38
# 18       7:15 PM         9:58
# 21       7:16 PM         9:33
# ..           ...          ...
# 524      9:56 PM         1:49
# 528      9:56 PM         1:12
# 533      9:58 PM         0:44
# 541     10:01 PM         0:31
# 545     10:02 PM         0:00
#
#                                        HOMEDESCRIPTION  \
# 3          MISS Mitchell 6' Driving Floating Jump Shot
# 8                   Mitchell Free Throw 1 of 2 (1 PTS)
# 13    Allen 2' Cutting Layup Shot (2 PTS) (Love 1 AST)
# 18                    LeVert Bad Pass Turnover (P1.T1)
# 21                       MISS LeVert 26' 3PT Jump Shot
# ..                                                 ...
# 524  Mitchell 27' 3PT Step Back Jump Shot (66 PTS) ...
# 528                      MISS LeVert 24' 3PT Jump Shot
# 533         Mitchell 27' 3PT Pullup Jump Shot (69 PTS)
# 541                Mitchell Free Throw 1 of 2 (70 PTS)
# 545                                               None
#
#                NEUTRALDESCRIPTION     VISITORDESCRIPTION  ...  \
# 3                            None                   None  ...
# 8                            None                   None  ...
# 13                           None                   None  ...
# 18                           None  DeRozan STEAL (1 STL)  ...
# 21                           None                   None  ...
# ..                            ...                    ...  ...
# 524                          None                   None  ...
# 528                          None                   None  ...
# 533                          None                   None  ...
# 541                          None                   None  ...
# 545  End of 1st OT (10:02 PM EST)                   None  ...
#
#     PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG  \
# 3                    None                      None                     1
# 8                    None                      None                     1
# 13                   None                      None                     1
# 18                   None                      None                     1
# 21                   None                      None                     1
# ..                    ...                       ...                   ...
# 524                  None                      None                     1
# 528                  None                      None                     1
# 533                  None                      None                     1
# 541                  None                      None                     1
# 545                  None                      None                     1
#
#      PCTIME_SECONDS EVENTMSGTYPE_1  EVENTMSGACTIONTYPE_1 PCTIME_SECONDS_1  \
# 3               677            4.0                   0.0            675.0
# 8               665            3.0                  12.0            665.0
# 13              638            6.0                   2.0            638.0
# 18              598            1.0                  41.0            594.0
# 21              573            4.0                   0.0            568.0
# ..              ...            ...                   ...              ...
# 524             109            2.0                   1.0            100.0
# 528              72            4.0                   0.0             71.0
# 533              44            6.0                   2.0             41.0
# 541              31            3.0                  12.0             31.0
# 545               0            NaN                   NaN              NaN
#
#     PLAYER1_TEAM_ID_1 POSSESSION_END  POSSESSION_TEAM_ABBREVIATION
# 3        1.610613e+09           True                           CLE
# 8        1.610613e+09           True                           CLE
# 13       1.610613e+09           True                           CLE
# 18       1.610613e+09           True                           CLE
# 21       1.610613e+09           True                           CLE
# ..                ...            ...                           ...
# 524      1.610613e+09           True                           CLE
# 528      1.610613e+09           True                           CLE
# 533      1.610613e+09           True                           CLE
# 541      1.610613e+09           True                           CLE
# 545               NaN           True                           CLE
#
# [114 rows x 41 columns]

# %%
#Find offensive rebounds
missedShots = df.index[df['EVENTMSGTYPE'] == 2].tolist()

CLE_OREB = []
for shot in missedShots:
    if df.loc[shot]['PLAYER1_TEAM_ABBREVIATION'] == "CLE" and df.loc[shot+1]['PLAYER1_TEAM_ABBREVIATION'] == "CLE" and df.loc[shot+1]['EVENTMSGTYPE'] == 4:
        #print(f'offensive rebound - LOC: {shot}')
        CLE_OREB.append(shot+1)

# %%
# df['new_column_name'] = df.apply(lambda x: my_function(x['value_1'], x['value_2']), axis=1)

def eventScore(before,after):

    start_score = str(before).split(" - ")
    end_score = str(after).split(" - ")

    diff_score = [int(x)-int(y) for x, y in zip(end_score, start_score)]

    return max(diff_score)

df['SCORE_CHANGE'] = df.apply(lambda row: eventScore(row['SCORE_1'],row['SCORE']), axis=1)

# %%
eventScore(8, df)
# Out:
# 1

# %%
df[df['PERIOD'] == 4].tail(15)
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 483  0022200552       692             6                   1       4
# 484  0022200552       694             3                  11       4
# 485  0022200552       695             8                   0       4
# 486  0022200552       696             8                   0       4
# 487  0022200552       697             8                   0       4
# 488  0022200552       701             3                  12       4
# 489  0022200552       702             4                   0       4
# 490  0022200552       703             1                  72       4
# 491  0022200552       705             9                   1       4
# 492  0022200552       706             8                   0       4
# 493  0022200552       707             8                   0       4
# 494  0022200552       708             8                   0       4
# 495  0022200552       712             2                  63       4
# 496  0022200552       713             4                   0       4
# 497  0022200552       714            13                   0       4
#
#     WCTIMESTRING PCTIMESTRING                      HOMEDESCRIPTION  \
# 483      9:42 PM         0:04                                 None
# 484      9:42 PM         0:04  Mitchell Free Throw 1 of 2 (56 PTS)
# 485      9:42 PM         0:04                 SUB: Lopez FOR Osman
# 486      9:42 PM         0:04                                 None
# 487      9:42 PM         0:04                                 None
# 488      9:42 PM         0:04      MISS Mitchell Free Throw 2 of 2
# 489      9:42 PM         0:03       Mitchell REBOUND (Off:3 Def:4)
# 490      9:44 PM         0:03   Mitchell 2' Putback Layup (58 PTS)
# 491      9:44 PM         0:03                                 None
# 492      9:44 PM         0:03                 SUB: Osman FOR Lopez
# 493      9:44 PM         0:03                                 None
# 494      9:44 PM         0:03                                 None
# 495      9:45 PM         0:00                                 None
# 496      9:45 PM         0:00                                 None
# 497      9:45 PM         0:00                                 None
#
#                   NEUTRALDESCRIPTION                      VISITORDESCRIPTION  \
# 483                             None     Dosunmu P.FOUL (P5.PN) (T.Brothers)
# 484                             None                                    None
# 485                             None                                    None
# 486                             None               SUB: Williams FOR Dosunmu
# 487                             None                 SUB: Drummond FOR White
# 488                             None                                    None
# 489                             None                                    None
# 490                             None                                    None
# 491                             None  Bulls Timeout: Regular (Reg.6 Short 0)
# 492                             None                                    None
# 493                             None                 SUB: White FOR Williams
# 494                             None               SUB: Dosunmu FOR Drummond
# 495                             None    MISS DeRozan 27' 3PT Fadeaway Jumper
# 496                             None                           Bulls Rebound
# 497  End of 4th Period (9:45 PM EST)                                    None
#
#      ... EVENTMSGTYPE_1 EVENTMSGACTIONTYPE_1  PCTIME_SECONDS_1  \
# 483  ...            3.0                 11.0               4.0
# 484  ...            8.0                  0.0               4.0
# 485  ...            8.0                  0.0               4.0
# 486  ...            8.0                  0.0               4.0
# 487  ...            3.0                 12.0               4.0
# 488  ...            4.0                  0.0               3.0
# 489  ...            1.0                 72.0               3.0
# 490  ...            9.0                  1.0               3.0
# 491  ...            8.0                  0.0               3.0
# 492  ...            8.0                  0.0               3.0
# 493  ...            8.0                  0.0               3.0
# 494  ...            2.0                 63.0               0.0
# 495  ...            4.0                  0.0               0.0
# 496  ...           13.0                  0.0               0.0
# 497  ...           12.0                  0.0             300.0
#
#      PLAYER1_TEAM_ID_1 POSSESSION_END  POSSESSION_TEAM_ABBREVIATION  \
# 483       1.610613e+09          False                           CHI
# 484       1.610613e+09          False                           CHI
# 485       1.610613e+09          False                           CHI
# 486       1.610613e+09          False                           CHI
# 487       1.610613e+09          False                           CHI
# 488       1.610613e+09          False                           CHI
# 489       1.610613e+09          False                           CHI
# 490                NaN           True                           CHI
# 491       1.610613e+09          False                           CLE
# 492       1.610613e+09          False                           CLE
# 493       1.610613e+09          False                           CLE
# 494       1.610613e+09          False                           CLE
# 495                NaN           True                           CLE
# 496                NaN          False                           CHI
# 497                NaN           True                           CHI
#
#     PLAYER1_TEAM_ID_0    SCORE_1 SCORE_CHANGE  SCORE_0
# 483      1.610613e+09  130 - 127            0      NaN
# 484      1.610613e+09  130 - 127            1      NaN
# 485      1.610613e+09  130 - 128            0      NaN
# 486      1.610613e+09  130 - 128            0      NaN
# 487      1.610613e+09  130 - 128            0      NaN
# 488      1.610613e+09  130 - 128            0      NaN
# 489      1.610613e+09  130 - 128            0      NaN
# 490      1.610613e+09  130 - 128            2      NaN
# 491      1.610613e+09  130 - 130            0      NaN
# 492               NaN  130 - 130            0      NaN
# 493      1.610613e+09  130 - 130            0      NaN
# 494      1.610613e+09  130 - 130            0      NaN
# 495      1.610613e+09  130 - 130            0      NaN
# 496      1.610613e+09  130 - 130            0      NaN
# 497               NaN  130 - 130            0      NaN
#
# [15 rows x 45 columns]

# %%
df.drop(['SCORE_0'],axis=1)
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0022200552         2            12                   0       1
# 1    0022200552         4            10                   0       1
# 2    0022200552         7             1                   1       1
# 3    0022200552         8             2                 101       1
# 4    0022200552         9             4                   0       1
# ..          ...       ...           ...                 ...     ...
# 541  0022200552       776             3                  11       5
# 542  0022200552       777             3                  12       5
# 543  0022200552       778             2                  79       5
# 544  0022200552       779             4                   0       5
# 545  0022200552       780            13                   0       5
#
#     WCTIMESTRING PCTIMESTRING                              HOMEDESCRIPTION  \
# 0        7:11 PM        12:00                                         None
# 1        7:11 PM        12:00  Jump Ball Allen vs. Vucevic: Tip to Dosunmu
# 2        7:12 PM        11:41                                         None
# 3        7:12 PM        11:17  MISS Mitchell 6' Driving Floating Jump Shot
# 4        7:12 PM        11:15                                         None
# ..           ...          ...                                          ...
# 541     10:01 PM         0:31          Mitchell Free Throw 1 of 2 (70 PTS)
# 542     10:02 PM         0:31          Mitchell Free Throw 2 of 2 (71 PTS)
# 543     10:02 PM         0:25                                         None
# 544     10:02 PM         0:22                  Allen REBOUND (Off:6 Def:2)
# 545     10:02 PM         0:00                                         None
#
#                     NEUTRALDESCRIPTION                    VISITORDESCRIPTION  \
# 0    Start of 1st Period (7:11 PM EST)                                  None
# 1                                 None                                  None
# 2                                 None     DeRozan 24' 3PT Jump Shot (3 PTS)
# 3                                 None                                  None
# 4                                 None         Vucevic REBOUND (Off:0 Def:1)
# ..                                 ...                                   ...
# 541                               None                                  None
# 542                               None                                  None
# 543                               None  MISS LaVine 36' 3PT Pullup Jump Shot
# 544                               None                                  None
# 545       End of 1st OT (10:02 PM EST)                                  None
#
#      ... PCTIME_SECONDS EVENTMSGTYPE_1  EVENTMSGACTIONTYPE_1  \
# 0    ...            720           10.0                   0.0
# 1    ...            720            1.0                   1.0
# 2    ...            701            2.0                 101.0
# 3    ...            677            4.0                   0.0
# 4    ...            675            2.0                  41.0
# ..   ...            ...            ...                   ...
# 541  ...             31            3.0                  12.0
# 542  ...             31            2.0                  79.0
# 543  ...             25            4.0                   0.0
# 544  ...             22           13.0                   0.0
# 545  ...              0            NaN                   NaN
#
#      PCTIME_SECONDS_1 PLAYER1_TEAM_ID_1  POSSESSION_END  \
# 0               720.0      1.610613e+09           False
# 1               701.0      1.610613e+09           False
# 2               677.0      1.610613e+09            True
# 3               675.0      1.610613e+09            True
# 4               670.0      1.610613e+09           False
# ..                ...               ...             ...
# 541              31.0      1.610613e+09           False
# 542              25.0      1.610613e+09            None
# 543              22.0      1.610613e+09            True
# 544               0.0               NaN           False
# 545               NaN               NaN            True
#
#     POSSESSION_TEAM_ABBREVIATION PLAYER1_TEAM_ID_0    SCORE_1  SCORE_CHANGE
# 0                            CHI               NaN      0 - 0             0
# 1                            CHI               NaN      0 - 0             0
# 2                            CHI      1.610613e+09      0 - 0             3
# 3                            CLE      1.610613e+09      3 - 0             0
# 4                            CHI      1.610613e+09      3 - 0             0
# ..                           ...               ...        ...           ...
# 541                          CLE      1.610613e+09  134 - 143             1
# 542                          CLE      1.610613e+09  134 - 144             1
# 543                          CLE      1.610613e+09  134 - 145             0
# 544                          CHI      1.610613e+09  134 - 145             0
# 545                          CHI      1.610613e+09  134 - 145             0
#
# [546 rows x 44 columns]

# %%
possessionChanges = df[df['POSSESSION_END'] == True].index.tolist()

# %%
possessionChanges
# Out:
# [2,
#  3,
#  5,
#  9,
#  11,
#  15,
#  17,
#  18,
#  19,
#  21,
#  23,
#  24,
#  26,
#  28,
#  30,
#  34,
#  35,
#  36,
#  37,
#  38,
#  42,
#  46,
#  47,
#  48,
#  49,
#  50,
#  51,
#  52,
#  58,
#  59,
#  62,
#  63,
#  64,
#  66,
#  69,
#  70,
#  79,
#  80,
#  82,
#  84,
#  86,
#  89,
#  91,
#  92,
#  93,
#  94,
#  97,
#  99,
#  101,
#  108,
#  109,
#  110,
#  111,
#  116,
#  117,
#  119,
#  120,
#  122,
#  126,
#  129,
#  131,
#  132,
#  136,
#  138,
#  140,
#  146,
#  149,
#  151,
#  153,
#  154,
#  155,
#  157,
#  159,
#  160,
#  161,
#  164,
#  166,
#  168,
#  170,
#  171,
#  175,
#  180,
#  181,
#  183,
#  185,
#  187,
#  188,
#  190,
#  195,
#  201,
#  202,
#  206,
#  207,
#  208,
#  212,
#  213,
#  215,
#  218,
#  222,
#  224,
#  228,
#  230,
#  235,
#  236,
#  238,
#  239,
#  240,
#  244,
#  245,
#  247,
#  249,
#  251,
#  253,
#  254,
#  255,
#  256,
#  258,
#  259,
#  263,
#  264,
#  266,
#  267,
#  269,
#  273,
#  274,
#  280,
#  282,
#  283,
#  284,
#  289,
#  296,
#  297,
#  301,
#  304,
#  306,
#  311,
#  312,
#  317,
#  318,
#  319,
#  321,
#  323,
#  331,
#  334,
#  335,
#  339,
#  340,
#  342,
#  343,
#  344,
#  349,
#  350,
#  351,
#  355,
#  364,
#  365,
#  367,
#  372,
#  373,
#  374,
#  375,
#  376,
#  378,
#  382,
#  383,
#  386,
#  390,
#  395,
#  397,
#  398,
#  400,
#  405,
#  406,
#  410,
#  411,
#  413,
#  417,
#  421,
#  426,
#  428,
#  433,
#  435,
#  438,
#  439,
#  441,
#  447,
#  448,
#  449,
#  450,
#  451,
#  452,
#  457,
#  459,
#  460,
#  464,
#  468,
#  472,
#  475,
#  477,
#  482,
#  490,
#  495,
#  497,
#  502,
#  503,
#  505,
#  508,
#  510,
#  512,
#  517,
#  518,
#  520,
#  522,
#  524,
#  527,
#  528,
#  531,
#  533,
#  539,
#  542,
#  543,
#  545]

# %%
possScore = []

for i in range(len(possessionChanges)-1):
    possScore.append(df.iloc[possessionChanges[i] + 1:possessionChanges[i+1] + 1]["SCORE_CHANGE"].sum())

# %%
possessionChanges = np.array(possessionChanges)

# %%
possessionChanges
# Out:
# array([  2,   3,   5,   9,  11,  15,  17,  18,  19,  21,  23,  24,  26,
#         28,  30,  34,  35,  36,  37,  38,  42,  46,  47,  48,  49,  50,
#         51,  52,  58,  59,  62,  63,  64,  66,  69,  70,  79,  80,  82,
#         84,  86,  89,  91,  92,  93,  94,  97,  99, 101, 108, 109, 110,
#        111, 116, 117, 119, 120, 122, 126, 129, 131, 132, 136, 138, 140,
#        146, 149, 151, 153, 154, 155, 157, 159, 160, 161, 164, 166, 168,
#        170, 171, 175, 180, 181, 183, 185, 187, 188, 190, 195, 201, 202,
#        206, 207, 208, 212, 213, 215, 218, 222, 224, 228, 230, 235, 236,
#        238, 239, 240, 244, 245, 247, 249, 251, 253, 254, 255, 256, 258,
#        259, 263, 264, 266, 267, 269, 273, 274, 280, 282, 283, 284, 289,
#        296, 297, 301, 304, 306, 311, 312, 317, 318, 319, 321, 323, 331,
#        334, 335, 339, 340, 342, 343, 344, 349, 350, 351, 355, 364, 365,
#        367, 372, 373, 374, 375, 376, 378, 382, 383, 386, 390, 395, 397,
#        398, 400, 405, 406, 410, 411, 413, 417, 421, 426, 428, 433, 435,
#        438, 439, 441, 447, 448, 449, 450, 451, 452, 457, 459, 460, 464,
#        468, 472, 475, 477, 482, 490, 495, 497, 502, 503, 505, 508, 510,
#        512, 517, 518, 520, 522, 524, 527, 528, 531, 533, 539, 542, 543,
#        545])

# %%
possessionChanges[possessionChanges > 72].min()
# Out:
# 79

# %%
CLE_OREB
# Out:
# [72, 104, 276, 303, 314, 389, 416, 423, 437, 471, 501, 516]

# %%
CLE_OREB_bounds = [[reb, possessionChanges[possessionChanges > reb].min()+1] for reb in CLE_OREB]

# %%
points = 0
for reb in CLE_OREB_bounds:
    points += df.iloc[reb[0]:reb[1]]["SCORE_CHANGE"].sum()

# %%
points / len(CLE_OREB)
# Out:
# 1.5833333333333333

# %% [markdown]
# ## Testing `nba_api` Endpoints

# %%
# Query for the regular season games of the Cavs (team no. 3 alphabetically)
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_ids[2], 
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']
game_IDs = [game['GAME_ID'] for game in games]

# %%
from nba_api.stats.endpoints import leagueleaders
from nba_api.stats.library.parameters import Season

leagueLead = leagueleaders.LeagueLeaders(league_id='00',
                                         per_mode48='PerGame',
                                         scope='S',
                                         season=Season.default,
                                         season_type_all_star='Regular Season',
                                         stat_category_abbreviation='PTS')

leaders = leagueLead.league_leaders.get_data_frame()

# %%
leaders.iloc[:30].to_csv('league_leaders.csv',index=False,mode='a')

# %%
base_url = 'https://stats.nba.com/stats/{endpoint}'
endpoint = 'leagueleaders'
url = 'https://stats.nba.com/stats/leagueleaders?ActiveFlag=&LeagueID=00&PerMode=PerGame&Scope=S&Season=2022-23&SeasonType=Regular+Season&StatCategory=PTS'

# %%
from nba_api.stats.endpoints import videoevents
from nba_api.stats.library.parameters import Season

game_id = "0022200552" # CHI @ CLE 02/01/23
game_event_id = "703" # D. Mitchell missed FT putback

gameLog = videoevents.VideoEvents(game_id=game_id,game_event_id=game_event_id)

# %%
from nba_api.stats.endpoints import videoevents

game_id = "0022200552" # CHI @ CLE 02/01/23
game_event_id = "703" # D. Mitchell missed FT putback

vidEvent = videoevents.VideoEvents(game_id=game_id,game_event_id=game_event_id)

# %%
vidEvent = vidEvent.get_normalized_dict()
vidEventDict = {
    'uuid': vidEvent['Meta']['videoUrls'][0]['uuid'],
    'game_id': vidEvent['playlist'][0]['gi'],
    'game_event_id': vidEvent['playlist'][0]['ei'],
    'year': vidEvent['playlist'][0]['y'],
    'month': vidEvent['playlist'][0]['m'],
    'day': vidEvent['playlist'][0]['d']
}
# Out:
# {'Meta': {'videoUrls': [{'uuid': '4549dfbf-fde2-4dcc-8065-afade5ada267',
#     'dur': None,
#     'stt': None,
#     'stp': None,
#     'sth': None,
#     'stw': None,
#     'mtt': None,
#     'mtp': None,
#     'mth': None,
#     'mtw': None,
#     'ltt': None,
#     'ltp': None,
#     'lth': None,
#     'ltw': None}]},
#  'playlist': [{'gi': '0022200552',
#    'ei': 703,
#    'y': 2023,
#    'm': '01',
#    'd': '02',
#    'gc': '2023-01-02/CHICLE',
#    'p': 4,
#    'dsc': "Mitchell 2' Putback Layup (58 PTS)",
#    'ha': 'CLE',
#    'va': 'CHI',
#    'hpb': 128,
#    'hpa': 130,
#    'vpb': 130,
#    'vpa': 130,
#    'pta': 0}]}

# %%
vid_UUID = vidEvent.get_normalized_dict()['Meta']['videoUrls'][0]['uuid']

# %%
#vidEndpoint = f'https://videos.nba.com/nba/pbp/media/{vid_year}/{vid_month}/{vid_day}/{game_id}/{game_event_id}/{vid_UUID}_{vid_resolution}.mp4'

vidEndpoint = 'https://videos.nba.com/nba/pbp/media/{}/{}/{}/{}/{}/{}_{}.mp4'

# %%
vidEndpoint.format('2023','01','02','0022200552','703',vid_UUID,'1280x720')
# Out:
# 'https://videos.nba.com/nba/pbp/media/2023/01/02/0022200552/703/4549dfbf-fde2-4dcc-8065-afade5ada267_1280x720.mp4'

# %%
from nba_api.stats.endpoints import leagueleaders
from nba_api.stats.library.parameters import Season


def get_data(cat, per_mode):

  leagueLead = leagueleaders.LeagueLeaders(league_id='00',
                                         per_mode48=per_mode,
                                         scope='S',
                                         season=Season.default,
                                         season_type_all_star='Regular Season',
                                         stat_category_abbreviation=cat)
  
  # Export just the top 30 to csv
  leaders = leagueLead.league_leaders.get_data_frame()
  csv_name = 'NBA_Leaders_' + cat + per_mode + '.csv'
  leaders.iloc[:30].to_csv(csv_name,index=False)


# Extract and export the info for each of the listed categories
categories = ['PTS', 'REB', 'AST', 'FG3_PCT']

for cat in categories:
  if cat == 'PTS':
    get_data(cat, 'PerGame')
    get_data(cat, 'Totals')
  else:
    per_mode = 'PerGame'
    get_data(cat, per_mode)
