# %% [markdown]
# # Average Shot Distance

# %%
import pandas as pd
import numpy as np
import yaml
from nba_api.stats.endpoints import shotchartdetail
from nba_api.stats.static import teams

# %%
# Get shot chart for entire league
shotdf = shotchartdetail.ShotChartDetail(
                team_id=0,
                player_id=0,
                context_measure_simple='FGA',
            ).get_data_frames()[0]

teams_list = teams.get_teams()

# %%
shotdf['POINT_VALUE'] = np.where(shotdf['SHOT_ZONE_BASIC'].str.contains('3'), '3', '2')

# Create aggregated dataframe for average distances
# Masks
is_three = shotdf['POINT_VALUE'] == '3'
is_two = shotdf['POINT_VALUE'] == '2'
made = shotdf['SHOT_MADE_FLAG'] == 1
missed = shotdf['SHOT_MADE_FLAG'] == 0

# Helper for agg
def agg_dist(df):
    return df.groupby('PLAYER_ID').agg(
        FGA=('SHOT_DISTANCE', 'count'),
        ALL_AVG_DISTANCE=('SHOT_DISTANCE', 'mean'),
        _3PT_AVG_DISTANCE=('SHOT_DISTANCE', lambda x: x[is_three.loc[x.index]].mean()),
        _2PT_AVG_DISTANCE=('SHOT_DISTANCE', lambda x: x[is_two.loc[x.index]].mean())
    ).rename(columns={
        '_3PT_AVG_DISTANCE': '3PT_AVG_DISTANCE',
        '_2PT_AVG_DISTANCE': '2PT_AVG_DISTANCE'
    })

# Full stats
all_df = agg_dist(shotdf).add_prefix('ALL_')
made_df = agg_dist(shotdf[made]).add_prefix('MADE_')
miss_df = agg_dist(shotdf[missed]).add_prefix('MISS_')

# Combine into one df
out = (
    all_df.join(made_df, how='outer')
          .join(miss_df, how='outer')
          .reset_index()
)

# Add player names and teams
names = shotdf[['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID']].drop_duplicates(subset=['PLAYER_ID'])
out = out.merge(names, on='PLAYER_ID', how='left')
out['TEAM_ABBREVIATION'] = out['TEAM_ID'].map({team['id']: team['abbreviation'] for team in teams_list})

# Filter and re-order
out = out[out.ALL_FGA > 100].sort_values('MADE_2PT_AVG_DISTANCE', ascending=False)
out.to_csv('SHOOTING_DISTANCE_24-25.csv')

# %%
def fmt(val):
    return f"{val:.3f}" if pd.notnull(val) else ""

shot_distance_list = [{
    'id': str(row.PLAYER_ID),
    'name': str(row.PLAYER_NAME),
    'team': str(row.TEAM_ABBREVIATION),
    'fga': str(row.ALL_FGA),
    'all_avg_dist': fmt(row.ALL_ALL_AVG_DISTANCE),
    '3pt_avg_dist': fmt(row.ALL_3PT_AVG_DISTANCE),
    '2pt_avg_dist': fmt(row.ALL_2PT_AVG_DISTANCE),
    'made_fga': str(row.MADE_FGA),
    'made_all_avg_dist': fmt(row.MADE_ALL_AVG_DISTANCE),
    'made_3pt_avg_dist': fmt(row.MADE_3PT_AVG_DISTANCE),
    'made_2pt_avg_dist': fmt(row.MADE_2PT_AVG_DISTANCE),
    'miss_fga': str(row.MISS_FGA),
    'miss_all_avg_dist': fmt(row.MISS_ALL_AVG_DISTANCE),
    'miss_3pt_avg_dist': fmt(row.MISS_3PT_AVG_DISTANCE),
    'miss_2pt_avg_dist': fmt(row.MISS_2PT_AVG_DISTANCE),
} for _, row in out.iterrows()]


with open('shot_distance.yml', 'w') as stream:
  yaml.dump(shot_distance_list, stream)

# %%
out.columns
# Out:
# Index(['PLAYER_ID', 'ALL_FGA', 'ALL_ALL_AVG_DISTANCE', 'ALL_3PT_AVG_DISTANCE',
#        'ALL_2PT_AVG_DISTANCE', 'MADE_FGA', 'MADE_ALL_AVG_DISTANCE',
#        'MADE_3PT_AVG_DISTANCE', 'MADE_2PT_AVG_DISTANCE', 'MISS_FGA',
#        'MISS_ALL_AVG_DISTANCE', 'MISS_3PT_AVG_DISTANCE',
#        'MISS_2PT_AVG_DISTANCE', 'PLAYER_NAME', 'TEAM_ID', 'TEAM_ABBREVIATION'],
#       dtype='object')

# %%
active_players = players.get_players()

# %%
test_id = '1630173'
active_players[id] ==
# Out:
# {'id': 1630173,
#  'full_name': 'Precious Achiuwa',
#  'first_name': 'Precious',
#  'last_name': 'Achiuwa',
#  'is_active': True}

# %%
player_id = active_players[0]['id']

# %%
shotdf = shotchartdetail.ShotChartDetail(
                team_id=0,
                player_id=0,
                context_measure_simple='FGA',
            ).get_data_frames()[0]

# %%
shotdf.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#        'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE',
#        'HTM', 'VTM'],
#       dtype='object')

# %%
shotdf.SHOT_ZONE_BASIC.unique()
# Out:
# array(['Restricted Area', 'Right Corner 3', 'In The Paint (Non-RA)',
#        'Mid-Range', 'Left Corner 3', 'Above the Break 3'], dtype=object)

# %%
unique_players = list(shotdf.PLAYER_ID.unique())

# %%
unique_players[0]
# Out:
# 1642258

# %%
shotdf[shotdf.PLAYER_ID == unique_players[0]]
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0022400001              7    1642258
# 9       Shot Chart Detail  0022400001             39    1642258
# 10      Shot Chart Detail  0022400001             46    1642258
# 11      Shot Chart Detail  0022400001             48    1642258
# 12      Shot Chart Detail  0022400001             50    1642258
# ...                   ...         ...            ...        ...
# 214532  Shot Chart Detail  0022401202            580    1642258
# 214533  Shot Chart Detail  0022401202            582    1642258
# 219191  Shot Chart Detail  0022401229             26    1642258
# 219238  Shot Chart Detail  0022401229            201    1642258
# 219243  Shot Chart Detail  0022401229            219    1642258
#
#                PLAYER_NAME     TEAM_ID      TEAM_NAME  PERIOD  \
# 0       Zaccharie Risacher  1610612737  Atlanta Hawks       1
# 9       Zaccharie Risacher  1610612737  Atlanta Hawks       1
# 10      Zaccharie Risacher  1610612737  Atlanta Hawks       1
# 11      Zaccharie Risacher  1610612737  Atlanta Hawks       1
# 12      Zaccharie Risacher  1610612737  Atlanta Hawks       1
# ...                    ...         ...            ...     ...
# 214532  Zaccharie Risacher  1610612737  Atlanta Hawks       4
# 214533  Zaccharie Risacher  1610612737  Atlanta Hawks       4
# 219191  Zaccharie Risacher  1610612737  Atlanta Hawks       1
# 219238  Zaccharie Risacher  1610612737  Atlanta Hawks       2
# 219243  Zaccharie Risacher  1610612737  Atlanta Hawks       2
#
#         MINUTES_REMAINING  SECONDS_REMAINING  ...        SHOT_ZONE_AREA  \
# 0                      11                 43  ...  Left Side Center(LC)
# 9                       9                 23  ...             Center(C)
# 10                      8                 50  ...             Center(C)
# 11                      8                 47  ...             Center(C)
# 12                      8                 46  ...             Center(C)
# ...                   ...                ...  ...                   ...
# 214532                  7                 20  ...          Left Side(L)
# 214533                  7                 14  ...             Center(C)
# 219191                 10                  2  ...  Left Side Center(LC)
# 219238                 10                 15  ...             Center(C)
# 219243                  9                  6  ...          Left Side(L)
#
#         SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0               24+ ft.            26  -168   205                   1
# 9       Less Than 8 ft.             1    10    13                   1
# 10             8-16 ft.            12    53   111                   1
# 11      Less Than 8 ft.             1   -10    17                   1
# 12      Less Than 8 ft.             1   -10     1                   1
# ...                 ...           ...   ...   ...                 ...
# 214532          24+ ft.            24  -238    39                   1
# 214533  Less Than 8 ft.             1    12    10                   1
# 219191          24+ ft.            26  -205   162                   1
# 219238  Less Than 8 ft.             3   -33    17                   1
# 219243         8-16 ft.            13  -137     9                   1
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    0   20241112  BOS  ATL
# 9                    1   20241112  BOS  ATL
# 10                   0   20241112  BOS  ATL
# 11                   0   20241112  BOS  ATL
# 12                   0   20241112  BOS  ATL
# ...                ...        ...  ...  ...
# 214532               0   20241211  NYK  ATL
# 214533               0   20241211  NYK  ATL
# 219191               0   20241214  MIL  ATL
# 219238               0   20241214  MIL  ATL
# 219243               1   20241214  MIL  ATL
#
# [779 rows x 24 columns]

# %%
shotdf[shotdf.SHOT_ZONE_BASIC.str.contains('3')]
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0022400001              7    1642258
# 2       Shot Chart Detail  0022400001             12    1628401
# 3       Shot Chart Detail  0022400001             21    1630552
# 4       Shot Chart Detail  0022400001             23    1627759
# 5       Shot Chart Detail  0022400001             31    1627759
# ...                   ...         ...            ...        ...
# 219521  Shot Chart Detail  0022401230            703    1641717
# 219522  Shot Chart Detail  0022401230            705    1630578
# 219523  Shot Chart Detail  0022401230            707    1627832
# 219524  Shot Chart Detail  0022401230            715    1629652
# 219526  Shot Chart Detail  0022401230            724    1630224
#
#                PLAYER_NAME     TEAM_ID              TEAM_NAME  PERIOD  \
# 0       Zaccharie Risacher  1610612737          Atlanta Hawks       1
# 2            Derrick White  1610612738         Boston Celtics       1
# 3            Jalen Johnson  1610612737          Atlanta Hawks       1
# 4             Jaylen Brown  1610612738         Boston Celtics       1
# 5             Jaylen Brown  1610612738         Boston Celtics       1
# ...                    ...         ...                    ...     ...
# 219521       Cason Wallace  1610612760  Oklahoma City Thunder       4
# 219522      Alperen Sengun  1610612745        Houston Rockets       4
# 219523       Fred VanVleet  1610612745        Houston Rockets       4
# 219524       Luguentz Dort  1610612760  Oklahoma City Thunder       4
# 219526         Jalen Green  1610612745        Houston Rockets       4
#
#         MINUTES_REMAINING  SECONDS_REMAINING  ...         SHOT_ZONE_AREA  \
# 0                      11                 43  ...   Left Side Center(LC)
# 2                      11                 24  ...   Left Side Center(LC)
# 3                      10                 50  ...  Right Side Center(RC)
# 4                      10                 35  ...  Right Side Center(RC)
# 5                      10                  6  ...           Left Side(L)
# ...                   ...                ...  ...                    ...
# 219521                  0                 54  ...  Right Side Center(RC)
# 219522                  0                 47  ...              Center(C)
# 219523                  0                 42  ...           Left Side(L)
# 219524                  0                 24  ...  Right Side Center(RC)
# 219526                  0                  0  ...   Left Side Center(LC)
#
#        SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0              24+ ft.            26  -168   205                   1
# 2              24+ ft.            28  -181   218                   1
# 3              24+ ft.            25   157   203                   1
# 4              24+ ft.            27   102   253                   1
# 5              24+ ft.            24  -228    85                   1
# ...                ...           ...   ...   ...                 ...
# 219521         24+ ft.            25   188   168                   1
# 219522         24+ ft.            25   -29   257                   1
# 219523         24+ ft.            22  -228   -17                   1
# 219524         24+ ft.            24   186   167                   1
# 219526         24+ ft.            25  -218   132                   1
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    0   20241112  BOS  ATL
# 2                    0   20241112  BOS  ATL
# 3                    1   20241112  BOS  ATL
# 4                    1   20241112  BOS  ATL
# 5                    0   20241112  BOS  ATL
# ...                ...        ...  ...  ...
# 219521               1   20241214  OKC  HOU
# 219522               0   20241214  OKC  HOU
# 219523               0   20241214  OKC  HOU
# 219524               1   20241214  OKC  HOU
# 219526               0   20241214  OKC  HOU
#
# [91943 rows x 24 columns]

# %%
shotdf['POINT_VALUE'] = np.where(shotdf['SHOT_ZONE_BASIC'].str.contains('3'), '3', '2')

# %%
shotdf.groupby('POINT_VALUE')['SHOT_DISTANCE'].mean()

# %%
# create mask columns
is_three = shotdf['POINT_VALUE'] == '3'
is_two = shotdf['POINT_VALUE'] == '2'

# group by player
out = shotdf.groupby('PLAYER_ID').agg(
    FGA=('SHOT_DISTANCE', 'count'),
    AVG_DISTANCE=('SHOT_DISTANCE', 'mean'),
    _3PT_AVG_DISTANCE=('SHOT_DISTANCE', lambda x: x[is_three].mean()),
    _2PT_AVG_DISTANCE=('SHOT_DISTANCE', lambda x: x[is_two].mean())
).reset_index()

# optional: rename columns to match spec exactly
out = out.rename(columns={
    '_3PT_AVG_DISTANCE': '3PT_AVG_DISTANCE',
    '_2PT_AVG_DISTANCE': '2PT_AVG_DISTANCE'
})

# %%
out
# Out:
#      PLAYER_ID   FGA  3PT_AVG_DISTANCE  2PT_AVG_DISTANCE
# 0         2544  1270         26.116751          7.027397
# 1       101108   583         25.149051         13.102804
# 2       200768   117         25.511628         12.129032
# 3       200782     7         25.333333         11.000000
# 4       201142  1124         25.018817          9.982713
# ..         ...   ...               ...               ...
# 561    1642461    34         23.764706          5.823529
# 562    1642484    33         25.350000         12.692308
# 563    1642502     2         23.000000          6.000000
# 564    1642505    30         24.190476          7.666667
# 565    1642530    30         25.391304         10.571429
#
# [566 rows x 4 columns]

# %%
# masks
is_three = shotdf['POINT_VALUE'] == '3'
is_two = shotdf['POINT_VALUE'] == '2'
made = shotdf['SHOT_MADE_FLAG'] == 1
missed = shotdf['SHOT_MADE_FLAG'] == 0

# helper for agg
def agg_dist(df):
    return df.groupby('PLAYER_ID').agg(
        FGA=('SHOT_DISTANCE', 'count'),
        ALL_AVG_DISTANCE=('SHOT_DISTANCE', 'mean'),
        _3PT_AVG_DISTANCE=('SHOT_DISTANCE', lambda x: x[is_three.loc[x.index]].mean()),
        _2PT_AVG_DISTANCE=('SHOT_DISTANCE', lambda x: x[is_two.loc[x.index]].mean())
    ).rename(columns={
        '_3PT_AVG_DISTANCE': '3PT_AVG_DISTANCE',
        '_2PT_AVG_DISTANCE': '2PT_AVG_DISTANCE'
    })

# full stats
all_df = agg_dist(shotdf).add_prefix('ALL_')
made_df = agg_dist(shotdf[made]).add_prefix('MADE_')
miss_df = agg_dist(shotdf[missed]).add_prefix('MISS_')

# combine
out = (
    all_df.join(made_df, how='outer')
          .join(miss_df, how='outer')
          .reset_index()
)

# %%
shotdf.to_csv('SHOT_CHART_DETAIL_24-25.csv')

# %%
out.to_csv('SHOOTING_DISTANCE_24-25.csv')

# %%
names = shotdf[['PLAYER_ID', 'PLAYER_NAME']].drop_duplicates()
out = out.merge(names, on='PLAYER_ID', how='left')

# %%
out[out.ALL_FGA > 100].sort_values('MADE_2PT_AVG_DISTANCE', ascending=False)
# Out:
#      PLAYER_ID  ALL_FGA  ALL_ALL_AVG_DISTANCE  ALL_3PT_AVG_DISTANCE  \
# 422    1631260      424             23.485849             25.175000
# 1       101108      583             20.727273             25.149051
# 16      201942     1308             14.837156             25.104000
# 54      203552      343             18.294461             24.752747
# 43      203114      337             16.623145             25.340909
# ..         ...      ...                   ...                   ...
# 520    1642270      334              5.410180             25.122449
# 13      201599      140              1.921429                   NaN
# 247    1630171      267             14.280899             23.768212
# 50      203497      510              1.931373                   NaN
# 178    1629020      121              7.785124             23.161290
#
#      ALL_2PT_AVG_DISTANCE  MADE_FGA  MADE_ALL_AVG_DISTANCE  \
# 422             13.984375     182.0              23.016484
# 1               13.102804     249.0              19.333333
# 16              12.411153     624.0              13.219551
# 54              10.993789     164.0              17.701220
# 43              11.009756     160.0              14.843750
# ..                    ...       ...                    ...
# 520              2.021053     180.0               3.316667
# 13               1.921429      91.0               1.439560
# 247              1.931034     124.0              11.419355
# 50               1.931373     341.0               1.082111
# 178              2.488889      59.0               4.457627
#
#      MADE_3PT_AVG_DISTANCE  MADE_2PT_AVG_DISTANCE  MISS_FGA  \
# 422              24.928571              12.500000     242.0
# 1                25.121429              11.899083     334.0
# 16               24.857143              11.409259     684.0
# 54               24.626506              10.604938     179.0
# 43               25.250000              10.383929     177.0
# ..                     ...                    ...       ...
# 520              25.071429               1.481928     154.0
# 13                     NaN               1.439560      49.0
# 247              23.589286               1.397059     143.0
# 50                     NaN               1.082111     169.0
# 178              23.444444               1.040000      62.0
#
#      MISS_ALL_AVG_DISTANCE  MISS_3PT_AVG_DISTANCE  MISS_2PT_AVG_DISTANCE  \
# 422              23.838843              25.359223              15.138889
# 1                21.766467              25.165939              14.352381
# 16               16.312865              25.228916              13.455598
# 54               18.837989              24.858586              11.387500
# 43               18.231638              25.392857              11.763441
# ..                     ...                    ...                    ...
# 520               7.857143              25.142857               2.773109
# 13                2.816327                    NaN               2.816327
# 247              16.762238              23.873684               2.687500
# 50                3.644970                    NaN               3.644970
# 178              10.951613              23.045455               4.300000
#
#          PLAYER_NAME_x      PLAYER_NAME_y
# 422           AJ Green           AJ Green
# 1           Chris Paul         Chris Paul
# 16       DeMar DeRozan      DeMar DeRozan
# 54          Seth Curry         Seth Curry
# 43     Khris Middleton    Khris Middleton
# ..                 ...                ...
# 520    Donovan Clingan    Donovan Clingan
# 13      DeAndre Jordan     DeAndre Jordan
# 247        Isaac Okoro        Isaac Okoro
# 50         Rudy Gobert        Rudy Gobert
# 178  Jarred Vanderbilt  Jarred Vanderbilt
#
# [415 rows x 15 columns]

# %%
shotdf[shotdf.PLAYER_ID == 1642530]
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 16259   Shot Chart Detail  0022400092            724    1642530
# 16262   Shot Chart Detail  0022400092            734    1642530
# 21944   Shot Chart Detail  0022400124            741    1642530
# 22652   Shot Chart Detail  0022400128            697    1642530
# 30867   Shot Chart Detail  0022400174            662    1642530
# 33851   Shot Chart Detail  0022400191            744    1642530
# 33853   Shot Chart Detail  0022400191            747    1642530
# 33857   Shot Chart Detail  0022400191            756    1642530
# 37160   Shot Chart Detail  0022400210            623    1642530
# 37176   Shot Chart Detail  0022400210            681    1642530
# 37187   Shot Chart Detail  0022400210            709    1642530
# 49980   Shot Chart Detail  0022400282            771    1642530
# 51940   Shot Chart Detail  0022400293            688    1642530
# 62522   Shot Chart Detail  0022400353            700    1642530
# 62539   Shot Chart Detail  0022400353            756    1642530
# 78014   Shot Chart Detail  0022400440            622    1642530
# 78025   Shot Chart Detail  0022400440            652    1642530
# 78034   Shot Chart Detail  0022400440            694    1642530
# 78042   Shot Chart Detail  0022400440            716    1642530
# 78043   Shot Chart Detail  0022400440            719    1642530
# 88437   Shot Chart Detail  0022400499            132    1642530
# 128511  Shot Chart Detail  0022400722            709    1642530
# 212968  Shot Chart Detail  0022401194            130    1642530
# 212970  Shot Chart Detail  0022401194            133    1642530
# 212983  Shot Chart Detail  0022401194            166    1642530
# 212984  Shot Chart Detail  0022401194            170    1642530
# 213030  Shot Chart Detail  0022401194            358    1642530
# 213066  Shot Chart Detail  0022401194            495    1642530
# 213108  Shot Chart Detail  0022401194            631    1642530
# 213122  Shot Chart Detail  0022401194            663    1642530
#
#           PLAYER_NAME     TEAM_ID          TEAM_NAME  PERIOD  \
# 16259   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 16262   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 21944   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 22652   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 30867   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 33851   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 33853   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 33857   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 37160   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 37176   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 37187   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 49980   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 51940   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 62522   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 62539   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 78014   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 78025   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 78034   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 78042   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 78043   Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 88437   Yuki Kawamura  1610612763  Memphis Grizzlies       1
# 128511  Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 212968  Yuki Kawamura  1610612763  Memphis Grizzlies       1
# 212970  Yuki Kawamura  1610612763  Memphis Grizzlies       1
# 212983  Yuki Kawamura  1610612763  Memphis Grizzlies       1
# 212984  Yuki Kawamura  1610612763  Memphis Grizzlies       1
# 213030  Yuki Kawamura  1610612763  Memphis Grizzlies       2
# 213066  Yuki Kawamura  1610612763  Memphis Grizzlies       3
# 213108  Yuki Kawamura  1610612763  Memphis Grizzlies       4
# 213122  Yuki Kawamura  1610612763  Memphis Grizzlies       4
#
#         MINUTES_REMAINING  SECONDS_REMAINING  ...  SHOT_ZONE_RANGE  \
# 16259                   1                 18  ...          24+ ft.
# 16262                   0                 43  ...          24+ ft.
# 21944                   0                 31  ...          24+ ft.
# 22652                   1                 21  ...          24+ ft.
# 30867                   1                 40  ...         8-16 ft.
# 33851                   1                 55  ...          24+ ft.
# 33853                   1                 44  ...          24+ ft.
# 33857                   0                 56  ...  Less Than 8 ft.
# 37160                   6                 36  ...          24+ ft.
# 37176                   3                  7  ...          24+ ft.
# 37187                   0                 40  ...        16-24 ft.
# 49980                   0                 52  ...          24+ ft.
# 51940                   0                 32  ...         8-16 ft.
# 62522                   5                  3  ...          24+ ft.
# 62539                   0                 54  ...          24+ ft.
# 78014                   9                  7  ...         8-16 ft.
# 78025                   6                 22  ...          24+ ft.
# 78034                   3                 53  ...          24+ ft.
# 78042                   2                  9  ...  Less Than 8 ft.
# 78043                   1                 53  ...          24+ ft.
# 88437                   2                 47  ...          24+ ft.
# 128511                  2                 43  ...          24+ ft.
# 212968                  3                 39  ...          24+ ft.
# 212970                  3                 15  ...         8-16 ft.
# 212983                  1                  3  ...          24+ ft.
# 212984                  0                 34  ...          24+ ft.
# 213030                  0                 53  ...          24+ ft.
# 213066                  3                 20  ...          24+ ft.
# 213108                  4                  1  ...          24+ ft.
# 213122                  0                 48  ...          24+ ft.
#
#        SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG  \
# 16259             26  -159   211                   1              0
# 16262             26   -98   244                   1              0
# 21944             25    29   254                   1              0
# 22652             26  -170   205                   1              0
# 30867             13    -7   136                   1              0
# 33851             26   100   247                   1              1
# 33853             26    69   251                   1              0
# 33857              2    18    18                   1              0
# 37160             28  -172   222                   1              0
# 37176             25   -72   246                   1              0
# 37187             17   -39   173                   1              1
# 49980             23   229    41                   1              0
# 51940             11    59   100                   1              1
# 62522             29    11   295                   1              0
# 62539             29   213   201                   1              1
# 78014             15  -110   116                   1              1
# 78025             26   179   193                   1              1
# 78034             25  -197   167                   1              0
# 78042              2    21     7                   1              1
# 78043             25   154   206                   1              1
# 88437             25   -33   250                   1              0
# 128511            23   234     8                   1              0
# 212968            22   229     1                   1              1
# 212970            14   -88   117                   1              0
# 212983            25   -54   246                   1              1
# 212984            25   113   225                   1              0
# 213030            24    98   224                   1              0
# 213066            25   -98   233                   1              1
# 213108            25  -142   216                   1              0
# 213122            25  -189   178                   1              0
#
#         GAME_DATE  HTM  VTM  POINT_VALUE
# 16259    20241026  MEM  ORL            3
# 16262    20241026  MEM  ORL            3
# 21944    20241030  MEM  BKN            3
# 22652    20241031  MEM  MIL            3
# 30867    20241106  MEM  LAL            2
# 33851    20241108  MEM  WAS            3
# 33853    20241108  MEM  WAS            3
# 33857    20241108  MEM  WAS            2
# 37160    20241110  POR  MEM            3
# 37176    20241110  POR  MEM            3
# 37187    20241110  POR  MEM            2
# 49980    20241125  MEM  POR            3
# 51940    20241127  MEM  DET            2
# 62522    20241208  WAS  MEM            3
# 62539    20241208  WAS  MEM            3
# 78014    20241229  OKC  MEM            2
# 78025    20241229  OKC  MEM            3
# 78034    20241229  OKC  MEM            3
# 78042    20241229  OKC  MEM            2
# 78043    20241229  OKC  MEM            3
# 88437    20250106  MEM  DAL            3
# 128511   20250205  TOR  MEM            3
# 212968   20250413  MEM  DAL            3
# 212970   20250413  MEM  DAL            2
# 212983   20250413  MEM  DAL            3
# 212984   20250413  MEM  DAL            3
# 213030   20250413  MEM  DAL            3
# 213066   20250413  MEM  DAL            3
# 213108   20250413  MEM  DAL            3
# 213122   20250413  MEM  DAL            3
#
# [30 rows x 25 columns]
